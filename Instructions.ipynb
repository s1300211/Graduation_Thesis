# %% [markdown]
# <a href="https://colab.research.google.com/github/s1300211/Graduation_Thesis/blob/master/Instructions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EBCF-CDEMを用いたDEMの超解像手順

# %% [markdown]
# ## **環境の準備**
# 以下の順番で進めます：<br>
# 1. WSL で Python + venv 作成
# 2. EBCF-CDEM の取得
# 3. 必要ライブラリのインストール
# 4. GeoTIFF → パッチ生成の準備

# %% [markdown]
# -----
# ### **1. WSL で Python + venv 作成**

# %% [markdown]
# ##### **1-1. システム更新**
# ```
# sudo apt update
# sudo apt upgrade -y
# ```

# %% [markdown]
# ##### **1-2. Python(3.10推奨)とpip、venvをインストール**
# ```
# sudo apt install -y python3 python3-pip python3-venv
# ```

# %% [markdown]
# ##### **1-3. 作業ディレクトリを作る**
# ```
# mkdir -p ~/workspace
# cd ~/workspace
# ```

# %% [markdown]
# ##### **1-4. venv仮想環境を作成**
# ```
# python3 -m venv venv
# ```

# %% [markdown]
# ##### **1-5. 仮想環境を有効化**
# ```
# source venv/bin/activate
# ```
# <br>

# %% [markdown]
# -----
# ### **2. EBCF-CDEM を取得**
# ```
# cd ~/workspace
# git clone https://github.com/AlcibiadesTophetScipio/EBCF-CDEM.git
# cd EBCF-CDEM
# ```
# <br>

# %% [markdown]
# --------
# ### **3. 依存ライブラリのインストール**
# リポジトリ内にある ``` requirements.txt ``` を使います。

# %% [markdown]
# ##### **3-1. 基本依存**
# ```
# pip install -r requirements.txt
# ```

# %% [markdown]
# ##### **3-2. GeoTIFF 処理・前処理に必要な追加ライブラリ**
# ```
# pip install rasterio numpy scipy scikit-image
# ```
# <br>

# %% [markdown]
# ------
# ### **4. GPU (CUDA) を使う場合 (任意)**
# WSL で NVIDIA GPU を使うなら、<br>
# WSL ホスト Windows 側に **CUDA Toolkit を入れ、<br>
# WSL 側に対応する PyTorch を入れます。
# ```
# pip install torch torchvision --index-url https://download.pytorch.org/whl/cu121
# ```
# CPU だけで進めるなら不要
# <br>
# <br>

# %% [markdown]
# -------
# ### **5. DEM 前処理（あなたの HR / LR データを扱う準備）**
# この時点で EBCF-CDEM の環境は整ったので、<br>
# 次は **GeoTIFF → NumPy パッチ作成の作業フォルダを作る** のが良いです。<br>
# 例：
# ```
# ~/workspace/
#     EBCF-CDEM/
#     moon_data/
#         hr_2m.tif
#         south_pole_5m.tif
# ```
# ```
# mkdir -p ~/workspace/moon_data
# ```
# ここにあなたの提供データ（2m DEM, 5m DEM）を置きます。
# <br>
# <br>

# %% [markdown]
# -------
# ### **6. ここまでで "環境が完全に準備完了"**
# まとめると、あなたの WSL 上はこうなっています：
# ```
# ~/workspace/
#     venv/  ← Python仮想環境
#     EBCF-CDEM/  ← GitHubから取得したSRモデル本体
#     moon_data/
#         hr_2m.tif
#         south_pole_5m.tif
#         preprocess_make_patches.py
# ```
# <br>

# %% [markdown]
# ----
# ## **1. 2m DEM から学習用パッチ（HR=2m / LR=4m）**

# %% [markdown]
# ### **1-1. 作業ディレクトリを作る**
# EBCF-CDEM リポジトリ直下でやる想定です：
# ```
# cd ~/Documents/EBCF-CDEM
#
# mkdir -p moon_data/raw
# mkdir -p moon_data/patches/HR
# mkdir -p moon_data/patches/LR
# mkdir -p moon_data/meta
# ```
# あなたの **2m DEM GeoTIFF** をここに置いてください：<br>
# ・ ```
# moon_data/raw/hr_2m.tif ```<br>
# ファイル名は違ってもOK。後で引数で渡します。

# %% [markdown]
# ### **1-2. パッチ生成スクリプト**
# ```
# nano moon_data/make_patches_2m_to_4m.py
# ```

# %% [markdown]
# ### **1-3. 実行（少数テスト）**
# まずは動作確認として 500 パッチだけ作ります：
# ```
# source ~/Documents/venv_2/bin/activate  # すでに有効なら不要
# cd ~/Documents/EBCF-CDEM
#
# python moon_data/make_patches_2m_to_4m.py \
#   --hr_tif moon_data/raw/hr_2m.tif \
#   --out_dir moon_data/patches \
#   --hr_size 256 \
#   --stride 128 \
#   --scale 2 \
#   --max_patches 500
# ```
# 成功すると：<br>
# * ```moon_data/patches/HR/patch_0000000.npy ...```
# * ```moon_data/patches/LR/patch_0000000.npy ...```
# * ```moon_data/meta/norm_stats.json``` (mu, sigma) <br>
# ができます。

# %% [markdown]
# ### **1-4. 作れたか確認**
# パッチ状態を確認：
# ```
# python - << 'EOF'
# import numpy as np
# from pathlib import Path
#
# hr = np.load(sorted(Path("moon_data/patches/HR").glob("*.npy"))[0])
# lr = np.load(sorted(Path("moon_data/patches/LR").glob("*.npy"))[0])
# print("HR:", hr.shape, hr.dtype, "min/max:", hr.min(), hr.max())
# print("LR:", lr.shape, lr.dtype, "min/max:", lr.min(), lr.max())
# EOF
# ```
# 期待値：<br>
# * HR shape: (256, 256)
# * LR shape: (128, 128)
# * dtype: float32<br>
# <br>

# %% [markdown]
# ---
# ## **2. EBCF-CDEM 学習用 JSON 生成**

# %% [markdown]
# ### **2-1. 学習用 JSON を作る（500パッチ用）**
# JSON生成スクリプトを作成
# ```
# cd ~/Documents/EBCF-CDEM
# nano moon_data/make_moon_json.py
# ```
# JSONを生成
# ```
# python moon_data/make_moon_json.py \
#   --hr_dir moon_data/patches/HR \
#   --lr_dir moon_data/patches/LR \
#   --out_json datasets/moon/moon_train_500.json \
#   --scale 2 \
#   --max_items 500
# ```
# <br>

# %% [markdown]
# ### **2-2. moon.yaml を作成**

# %% [markdown]
# ### **2-3. JSON のキー名があっているかを一発で確認**

# %% [markdown]
# ## **3. 学習コマンドを通す**

# %% [markdown]
# ---
# ## **全体フロー（どのケースでも共通）**
#
# 1. **HR(2m) からパッチ作成**（HR.npy / LR.npyを作る）
# 2. **split_json 作成**（train/test のファイル名リスト）
# 3. **moon.yaml（root_path/splitfile）更新**
# 4. **学習（hydra_run.py）**
# 5. **推論（infer...py）** : 5m→4m (resample) →2m（モデル）
# 6. **評価 (downsample consistency / slope / mask)**

# %% [markdown]
# ---
# ## **ケース別：何を実行し直すか**
# ### **Case 1) 学習用DEM（2m HR）を変えた**
# 例：別の2m DEMに差し替え、または範囲を変えた<br><br>
# やり直すもの（必須）：
# 1. **パッチ生成をやり直す**
#     * `moon_data/make_patches_2m_to_4m.py`
# 2. **split_json を作り直す**
#     * `datasets/moon/moon_train_XXX_split.json` を新規作成（または更新）
# 3. **moon.yaml を更新**
#     * `root_path`（パッチのHR/LRの場所）
#     * `split_file`（新しいjson）
# 4. **学習をやり直す**
#     * `hydra_run.py ... datasets@dataset_spec=moon ...`
# <br>やり直さなくていい：
# * 推論スクリプト（infer_full...）のコード自体
#   ※ただし「正規化／入力スケール方式」を変えたなら、そのパラメータは揃える

# %% [markdown]
# ---
# ### **Case 2) テスト用DEMだけ変えた（推論対象の5m DEMを変えた）**
# 例：別地域の5m、全域ファイルを変えた、center_tileだけ変えた<br><br>
# やり直すもの（必須）：
# 1. **推論だけやり直す**
#     * 小領域 : `infer_center_tile...py`
#     * 全域 : `infer_full_5m_to_2m_tiled.py`
# 2. **評価をやり直す**
#     * downsample consistency / slope / mask の評価スクリプト
#
# <br>やり直さなくていい：
# * 学習（モデルは同じでOK）
# * パッチ生成 / split_json / moon.yaml（学習データを変えてないなら不要）

# %% [markdown]
# ---
# ### **Case 3) 学習用パッチ数（500→2000など）だけ変えた**
# やり直すもの（必須）：
# 1. `make_patches_2m_to_4m.py`を **max_patches** 変えて再実行
# 2. split_json を作り直す（n_train/n_test も変える）
# 4. 学習をやり直す

# %% [markdown]
# ---
# ### **Case 4) パッチ作成パラメータを変えた（hr_size/stride/scale/nodata）**
# 例：`hr_size=256→512`、stride変更、scale変更<br><br>
# やり直すもの（必須）：
# 1. Case1 と同じ（パッチを作り直す＝学習やり直し）

# %% [markdown]
# ---
# ## **じっっこうコマンドの「順番」まとめ（テンプレ）**
# ### **A) 学習用DEMを変えた時（最小）**

# %% [markdown]
# ### **B) テスト用DEM（推論入力）だけ変えた時（最小）**

# %% [markdown]
# ## **重要な注意（ここだけ覚えておけば事故らない）**
# * **学習用DEMを変えたら**：パッチ→split→yaml→学習 を全部やり直す
# * **テスト用DEMだけ変えたら**：推論→評価だけやり直す
# * **全域推論は保存OFF**（今回の修正を維持）
