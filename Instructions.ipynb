# %% [markdown]
# <a href="https://colab.research.google.com/github/s1300211/Graduation_Thesis/blob/master/Instructions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EBCF-CDEMを用いたDEMの超解像手順

# %% [markdown]
# ## **環境の準備**
# 以下の順番で進めます：<br>
# 1. WSL で Python + venv 作成
# 2. EBCF-CDEM の取得
# 3. 必要ライブラリのインストール
# 4. GeoTIFF → パッチ生成の準備

# %% [markdown]
# -----
# ### **1. WSL で Python + venv 作成**

# %% [markdown]
# ##### **1-1. システム更新**
# ```
# sudo apt update
# sudo apt upgrade -y
# ```

# %% [markdown]
# ##### **1-2. Python(3.10推奨)とpip、venvをインストール**
# ```
# sudo apt install -y python3 python3-pip python3-venv
# ```

# %% [markdown]
# ##### **1-3. 作業ディレクトリを作る**
# ```
# mkdir -p ~/workspace
# cd ~/workspace
# ```

# %% [markdown]
# ##### **1-4. venv仮想環境を作成**
# ```
# python3 -m venv venv
# ```

# %% [markdown]
# ##### **1-5. 仮想環境を有効化**
# ```
# source venv/bin/activate
# ```
# <br>

# %% [markdown]
# -----
# ### **2. EBCF-CDEM を取得**
# ```
# cd ~/workspace
# git clone https://github.com/AlcibiadesTophetScipio/EBCF-CDEM.git
# cd EBCF-CDEM
# ```
# <br>

# %% [markdown]
# --------
# ### **3. 依存ライブラリのインストール**
# リポジトリ内にある ``` requirements.txt ``` を使います。

# %% [markdown]
# ##### **3-1. 基本依存**
# ```
# pip install -r requirements.txt
# ```

# %% [markdown]
# ##### **3-2. GeoTIFF 処理・前処理に必要な追加ライブラリ**
# ```
# pip install rasterio numpy scipy scikit-image
# ```
# <br>

# %% [markdown]
# ------
# ### **4. GPU (CUDA) を使う場合 (任意)**
# WSL で NVIDIA GPU を使うなら、<br>
# WSL ホスト Windows 側に **CUDA Toolkit を入れ、<br>
# WSL 側に対応する PyTorch を入れます。
# ```
# pip install torch torchvision --index-url https://download.pytorch.org/whl/cu121
# ```
# CPU だけで進めるなら不要
# <br>
# <br>

# %% [markdown]
# -------
# ### **5. DEM 前処理（あなたの HR / LR データを扱う準備）**
# この時点で EBCF-CDEM の環境は整ったので、<br>
# 次は **GeoTIFF → NumPy パッチ作成の作業フォルダを作る** のが良いです。<br>
# 例：
# ```
# ~/workspace/
#     EBCF-CDEM/
#     moon_data/
#         hr_2m.tif
#         south_pole_5m.tif
# ```
# ```
# mkdir -p ~/workspace/moon_data
# ```
# ここにあなたの提供データ（2m DEM, 5m DEM）を置きます。
# <br>
# <br>

# %% [markdown]
# -------
# ### **6. ここまでで "環境が完全に準備完了"**
# まとめると、あなたの WSL 上はこうなっています：
# ```
# ~/workspace/
#     venv/  ← Python仮想環境
#     EBCF-CDEM/  ← GitHubから取得したSRモデル本体
#     moon_data/
#         hr_2m.tif
#         south_pole_5m.tif
#         preprocess_make_patches.py
# ```
# <br>

# %% [markdown]
# ----
# ### **1. 2m DEM から学習用パッチ（HR=2m / LR=4m）**

# %% [markdown]
# ##### **1-1. 作業ディレクトリを作る**
# EBCF-CDEM リポジトリ直下でやる想定です：
# ```
# cd ~/Documents/EBCF-CDEM
#
# mkdir -p moon_data/raw
# mkdir -p moon_data/patches/HR
# mkdir -p moon_data/patches/LR
# mkdir -p moon_data/meta
# ```
# あなたの **2m DEM GeoTIFF** をここに置いてください：<br>
# ・ ```
# moon_data/raw/hr_2m.tif ```<br>
# ファイル名は違ってもOK。後で引数で渡します。

# %% [markdown]
# ##### **1-2. パッチ生成スクリプトを作る**
# ```
# nano moon_data/make_patches_2m_to_4m.py
# ```
# 以下を**そのまま張り付けて**保存してください：
# ```
# #!/usr/bin/env python3
# import argparse
# import json
# from pathlib import Path
#
# import numpy as np
# import rasterio
# from rasterio.windows import Window
# from skimage.transform import resize
#
#
# def compute_mu_sigma(src_path: Path, sample_step: int = 1_000_000):
#     """
#     DEM全体から(μ,σ)を計算。
#     巨大DEMでも回るようにサンプリング対応（sample_step間引き）。
#     """
#     with rasterio.open(src_path) as src:
#         arr = src.read(1).astype(np.float32)
#     flat = arr.reshape(-1)
#     # NaNがある場合に備える
#     flat = flat[np.isfinite(flat)]
#     if flat.size == 0:
#         raise RuntimeError("All values are NaN/Inf. Check your DEM.")
#     if sample_step and flat.size > sample_step:
#         idx = np.random.choice(flat.size, size=sample_step, replace=False)
#         flat = flat[idx]
#     mu = float(flat.mean())
#     sigma = float(flat.std())
#     if sigma == 0.0:
#         raise RuntimeError("sigma == 0. DEM looks constant.")
#     return mu, sigma
#
#
# def main():
#     ap = argparse.ArgumentParser()
#     ap.add_argument("--hr_tif", type=str, required=True, help="HR 2m GeoTIFF path")
#     ap.add_argument("--out_dir", type=str, required=True, help="Output root dir")
#     ap.add_argument("--hr_size", type=int, default=256, help="HR patch size (pixels)")
#     ap.add_argument("--stride", type=int, default=128, help="Stride in HR pixels")
#     ap.add_argument("--scale", type=int, default=2, help="SR scale (HR/LR). Use 2.")
#     ap.add_argument("--nodata", type=float, default=None, help="Optional nodata value (if known)")
#     ap.add_argument("--max_patches", type=int, default=-1, help="Limit number of patches for quick tests")
#     args = ap.parse_args()
#
#     hr_tif = Path(args.hr_tif)
#     out_dir = Path(args.out_dir)
#     hr_dir = out_dir / "HR"
#     lr_dir = out_dir / "LR"
#     meta_dir = out_dir.parent / "meta"
#     hr_dir.mkdir(parents=True, exist_ok=True)
#     lr_dir.mkdir(parents=True, exist_ok=True)
#     meta_dir.mkdir(parents=True, exist_ok=True)
#
#     hr_size = args.hr_size
#     stride = args.stride
#     scale = args.scale
#     lr_size = hr_size // scale
#     if hr_size % scale != 0:
#         raise ValueError("hr_size must be divisible by scale.")
#
#     # (μ, σ)を計算して保存（学習・推論で必ず同じ値を使う）
#     mu, sigma = compute_mu_sigma(hr_tif)
#     stats_path = meta_dir / "norm_stats.json"
#     stats_path.write_text(json.dumps({"mu": mu, "sigma": sigma}, indent=2))
#     print(f"[INFO] Saved normalization stats: {stats_path} (mu={mu:.6f}, sigma={sigma:.6f})")
#
#     patch_id = 0
#
#     with rasterio.open(hr_tif) as src:
#         H, W = src.height, src.width
#         src_nodata = src.nodata
#         nodata = args.nodata if args.nodata is not None else src_nodata
#
#         print(f"[INFO] HR size: {H}x{W}, nodata={nodata}")
#
#         for y in range(0, H - hr_size + 1, stride):
#             for x in range(0, W - hr_size + 1, stride):
#                 win = Window(x, y, hr_size, hr_size)
#                 patch_hr = src.read(1, window=win).astype(np.float32)
#
#                 # nodata / NaN を弾く：パッチに多く含まれると学習が壊れる
#                 if nodata is not None:
#                     bad = (patch_hr == nodata) | (~np.isfinite(patch_hr))
#                 else:
#                     bad = ~np.isfinite(patch_hr)
#                 if bad.mean() > 0.01:  # 1% 以上欠損があるパッチは捨てる
#                     continue
#
#                 # z-score 正規化
#                 patch_hr = (patch_hr - mu) / sigma
#
#                 # HR(2m) -> LR(4m) を作成（cubic + anti_alias）
#                 patch_lr = resize(
#                     patch_hr,
#                     (lr_size, lr_size),
#                     order=3,
#                     anti_aliasing=True,
#                     preserve_range=True,
#                 ).astype(np.float32)
#
#                 np.save(hr_dir / f"patch_{patch_id:07d}.npy", patch_hr)
#                 np.save(lr_dir / f"patch_{patch_id:07d}.npy", patch_lr)
#
#                 patch_id += 1
#                 if patch_id % 500 == 0:
#                     print(f"[INFO] patches: {patch_id}")
#
#                 if args.max_patches > 0 and patch_id >= args.max_patches:
#                     print("[INFO] max_patches reached; stopping.")
#                     break
#             if args.max_patches > 0 and patch_id >= args.max_patches:
#                 break
#
#     print(f"[DONE] total patches saved: {patch_id}")
#     print(f"[DONE] HR dir: {hr_dir}")
#     print(f"[DONE] LR dir: {lr_dir}")
#
#
# if __name__ == "__main__":
#     main()
# ```

# %% [markdown]
# ##### **1-3. 実行（まずは少数でテスト）**
# まずは動作確認として 500 パッチだけ作ります：
# ```
# source ~/Documents/venv_2/bin/activate  # すでに有効なら不要
# cd ~/Documents/EBCF-CDEM
#
# python moon_data/make_patches_2m_to_4m.py \
#   --hr_tif moon_data/raw/hr_2m.tif \
#   --out_dir moon_data/patches \
#   --hr_size 256 \
#   --stride 128 \
#   --scale 2 \
#   --max_patches 500
# ```
# 成功すると：<br>
# * ```moon_data/patches/HR/patch_0000000.npy ...```
# * ```moon_data/patches/LR/patch_0000000.npy ...```
# * ```moon_data/meta/norm_stats.json``` (mu, sigma) <br>
# ができます。
