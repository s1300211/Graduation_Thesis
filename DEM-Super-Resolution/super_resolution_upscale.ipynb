# %% [markdown]
# ### DEM Super Resolution Upscaling
#
# The openly available SuperResolution model is from this paper: 2023 _"A Global-Information-Constrained Deep Learning Network for Digital Elevation Model Super-Resolution"_ (https://www.mdpi.com/2072-4292/15/2/305)

# %% [markdown]
# ### ノートブックの概要: DEM超解像度アップスケーリング
#
# このノートブックは、デジタル標高モデル（DEM）の解像度を向上させるために、超解像度敵対的生成ネットワーク（SRGAN）を実装しています。このアーキテクチャは、「グローバル情報制約付き深層学習ネットワークによるデジタル標高モデル超解像度」と題された研究論文に基づいています。
#
# 以下の主要な段階をカバーしています。
#
# 1.  **環境設定とライブラリのインポート:** 必要なライブラリをインポートし、データアクセス用にGoogle Driveをマウントします。
# 2.  **モデルアーキテクチャの定義:** ジェネレータ、ディスクリミネータ、特徴抽出器、およびカスタムRMSE損失関数を定義します。
# 3.  **データ準備:** サンプルのDEMを読み込み、高解像度（HR）タイルに分割し、対応する低解像度（LR）タイルを生成し、トレーニング用のPyTorchデータセットを作成します。
# 4.  **モデルトレーニング:** ハイパーパラメータ、最適化アルゴリズムを設定し、SRGANモデルのトレーニングループを実行します。
# 5.  **モデルテストと再構築:** トレーニング済みモデルを読み込み、新しいLRタイルに適用してHR予測を生成し、その後、完全な超解像度DEMを再構築します。

# %% [markdown]
# ### 各セクションの詳細な要約:
#
# #### **1. セットアップとライブラリ (`n_UF5pPbuThk` - `DswtP0uiynWp` セル)**
#
# *   **`google.colab.drive`**: Google Driveをマウントするために使用され、ノートブックがユーザーのDriveに保存されたファイルにアクセスできるようになります。
# *   **`skimage`, `os`, `numpy`, `math`, `itertools`, `sys`, `torchvision`, `torch`, `torch.nn`, `torch.nn.functional`, `glob`, `random`, `PIL.Image`, `time`, `datetime`, `torch.utils.tensorboard`, `tifffile`**: これらのライブラリは、画像処理、数値演算、深層学習モデルの定義とトレーニング（PyTorch）、ファイルシステム操作、ロギングなど、さまざまなタスクのためにインポートされます。

# %% [markdown]
# #### **2. モデルアーキテクチャ (`u1kvDx5PyaEI` - `qiLjiK735uIP` セル)**
#
# *   **`FeatureExtractor`**: 画像から特徴を抽出するニューラルネットワークです。VGG19モデルに基づいており、トレーニング中に知覚損失を計算するために使用されます。
# *   **`ResidualBlock`**: ジェネレータの基本的な構成要素であり、深いネットワークのトレーニングの安定性とパフォーマンスを向上させるように設計されています。
# *   **`GeneratorResNet`**: コアとなる超解像度モデルです。低解像度（LR）DEMを入力として受け取り、高解像度（HR）DEMを出力することを目指します。残差ブロックとピクセルシャッフル層をアップサンプリングに利用します。
# *   **`C` (Discriminator Network)**: 真のHR DEMと生成されたHR DEMを区別しようとする畳み込みニューラルネットワークです。これは敵対的トレーニングプロセスにとって重要です。
# *   **`RMSELoss`**: 予測されたDEM値と真のDEM値の差を測定するために使用される、ルート平均二乗誤差損失関数のカスタム実装です。
# *   **`ImageDataset`**: DEM画像を読み込み、正規化を実行し、トレーニングのためにLRとHRのペアに分割する役割を担うカスタムPyTorch `Dataset`クラスです。

# %% [markdown]
# #### **3. データ準備 (`8mzjS_5yww_3` - `-G86sXMTcDuQ` セル)**
#
# *   **読み込みとタイリング**: `rasterio` を使用して、元の高解像度画像 `center_tile.tif` が読み込まれます。この大きな画像は、その後、小さな64x64ピクセルのタイル (`images_tiles`) に分割されます。
# *   **HRタイルの保存**: 64x64の高解像度タイルは、Google Driveに `hr_*.tif` ファイルとして保存されます。
# *   **LRタイルの生成**: 各HRタイルに対して、対応するLRタイルが次のように作成されます。
#     *   最近傍補間 (`gdal` および `numpy`) を使用して、HRタイルを半分の解像度（32x32）にダウンサンプリングします。
#     *   順序0（最近傍）補間 (`scipy.ndimage.zoom`) を使用して、32x32のLRタイルを64x64にアップサンプリングします。これにより、ピクセル化されたLRバージョンが作成されます。
#     *   元のHRタイルと生成されたLRタイルを水平方向に連結して、`ImageDataset`で利用される結合された `m*.tif` 画像を形成します。

# %% [markdown]
# #### **4. モデルトレーニング (`cMDkVeXPkg5x` - `5p0yVS5XkMpy` セル)**
#
# *   **ハイパーパラメータ**: `n_epochs`、`batch_size`、`learning_rate`、`hr_height`、`hr_width`のような主要なトレーニングパラメータが定義されます。
# *   **モデル初期化**: `GeneratorResNet`、`C` (ディスクリミネータ)、`FeatureExtractor`モデルが初期化されます。CUDAが利用可能な場合、GPUに移動されます。
# *   **損失関数**: `RMSELoss`は敵対的損失と直接的なピクセル単位の比較の両方に使用され、`torch.nn.L1Loss`はコンテンツ損失（`FeatureExtractor`を介した知覚損失）に使用されます。
# *   **オプティマイザ**: ジェネレータとディスクリミネータの両方にAdamオプティマイザが設定されます。
# *   **トレーニングループ**: コードはエポックとバッチを反復します。
#     *   **ジェネレータトレーニング**: LR入力からHR画像を生成します。ジェネレータの損失は、コンテンツ損失（生成された画像と実際のHR画像からの特徴間のL1損失）、敵対的損失（ディスクリミネータから）、および生成されたHR画像と実際のHR画像間の直接的なRMSE損失で構成されます。
#     *   **ディスクリミネータトレーニング**: 実際のHR画像と偽のHR画像を区別するようにトレーニングされます。その損失は、実際のHR画像を「有効」として正しく分類する能力と、生成されたHR画像を「偽」として分類する能力の組み合わせです。
# *   **ロギングとチェックポイント**: トレーニングの進行状況（G損失）が出力され、中間的に生成された画像が`sample_interval`で保存されます。モデルの重みは`checkpoint_interval`エポックで保存されます。

# %% [markdown]
# #### **5. 損失の可視化 (`nNQ8sQ9c0xTX` - `cTuS1KlqiQH2` セル)**
#
# *   トレーニング後、記録されたジェネレータの損失値（`loss_list`）がトレーニングエポックに対してプロットされ、学習曲線が視覚化されます。

# %% [markdown]
# #### **6. モデルテストと再構築 (`TC__6Vcjt5Hs` - `Wcz-PgdWRzpB` セル)**
#
# *   **モデルの再インポートと読み込み**: 必要なライブラリが再インポートされ、トレーニング済みの`GeneratorResNet`モデル（具体的には`generator_240.pth`チェックポイント）が読み込まれます。
# *   **テストデータ準備**: テスト用の`center_tile.tif`が読み込まれ、トレーニングデータと同様に64x64タイルに分割されます。重要なステップは、すべてのジェネレータへの入力タイルが64x64であることを保証するために、正確に64x64でないエッジタイルを隣接するタイルからのデータでパディングすることです。このパディング情報は後で元に戻すために保存されます。
# *   **超解像度推論**: 準備された各LRテストタイルは、読み込まれたジェネレータモデルを通過します。モデルは超解像度HRタイルを出力します。生成された出力は、元の標高値範囲に戻すために非正規化ステップを受けます。
# *   **タイル再構築**: 生成されたHRタイルが収集されます。準備中に適用されたパディングは削除されます。最後に、これらの処理されたHRタイルは、元のグリッドレイアウトで結合され、完全な超解像度DEM画像が再構築されます。最終的に再構築された画像は`gene_test_imge.tif`として保存されます。

# %%
import rasterio
import numpy as np

# ご自身のトレーニング用オリジナルDEMのパスを指定してください
fp_your_dem = r"/home/s1300211/Documents/datasets/training/NAC_DTM_A17_1500.tif" # このパスをご自身のトレーニング用DEMのパスに置き換えてください

with rasterio.open(fp_your_dem) as src:
    your_dem_data = src.read(1) # 最初のバンドを読み込む

# 欠損値（NaN）を除外して最小値と最大値を計算する
# もしDEMに欠損値がないと確信できる場合は、np.nanmin/np.nanmaxの代わりにnp.min/np.maxを使用できます。
min_val = np.nanmin(your_dem_data)
max_val = np.nanmax(your_dem_data)

print(f"ご自身のDEMデータの最小値: {min_val}")
print(f"ご自身のDEMデータの最大値: {max_val}")
# Out:
# ご自身のDEMデータの最小値: -1310.47265625
# ご自身のDEMデータの最大値: -1176.5936279296875

# %%
# Google Colab環境でのマウント（ローカル環境では不要）
# from google.colab import drive
# drive.mount("/content/drive")

# %%
import subprocess
import sys

# 必要なパッケージをインストール
packages = ['torch', 'torchvision', 'torchaudio', 'scikit-image', 'scipy', 'rasterio', 'tifffile']
print("Installing required packages...")
for package in packages:
    try:
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', package])
        print(f"✓ {package} installed successfully")
    except:
        print(f"⚠ {package} installation attempted")
print("Done!")
# Out:
# Installing required packages...
# ✓ torch installed successfully
# ✓ torch installed successfully
# ✓ torchvision installed successfully
# ✓ torchvision installed successfully
# ✓ torchaudio installed successfully
# ✓ torchaudio installed successfully
# ✓ scikit-image installed successfully
# ✓ scikit-image installed successfully
# ✓ scipy installed successfully
# ✓ scipy installed successfully
# ✓ rasterio installed successfully
# ✓ rasterio installed successfully
# ✓ tifffile installed successfully
# Done!
# ✓ tifffile installed successfully
# Done!

# %%
# ================================
# パス設定（ローカル環境用）
# ================================
# Google Colabではなくローカル環境で実行する場合は、以下のパスを変更してください

import os

# 基本ディレクトリ
BASE_DIR = "/home/s1300211/Documents"  # あなたの作業ディレクトリに変更してください
DATASET_DIR = os.path.join(BASE_DIR, "DEM-Super-Resolution", "dataset")  # データセットディレクトリ
MODEL_DIR = os.path.join(BASE_DIR, "DEM-Super-Resolution", "models")  # モデル保存ディレクトリ
CHECKPOINT_DIR = os.path.join(BASE_DIR, "DEM-Super-Resolution", "checkpoint")  # チェックポイント保存ディレクトリ

# ディレクトリが存在しない場合は作成
for dir_path in [DATASET_DIR, MODEL_DIR, CHECKPOINT_DIR]:
    os.makedirs(dir_path, exist_ok=True)

# DEM入出力ファイルパス（ご自身のDEMファイルパスに変更してください）
DEM_TRAIN_PATH = os.path.join(BASE_DIR, "datasets", "your_training_dem.tif")  # トレーニング用DEM
DEM_TEST_PATH = os.path.join(BASE_DIR, "datasets", "your_test_dem.tif")  # テスト用DEM

print(f"Dataset directory: {DATASET_DIR}")
print(f"Model directory: {MODEL_DIR}")
print(f"Checkpoint directory: {CHECKPOINT_DIR}")
# Out:
# Dataset directory: /home/s1300211/Documents/DEM-Super-Resolution/dataset
# Model directory: /home/s1300211/Documents/DEM-Super-Resolution/models
# Checkpoint directory: /home/s1300211/Documents/DEM-Super-Resolution/checkpoint

# %%
# import libraries
import argparse
from skimage import io
import os
import numpy as np
import math
import itertools
import sys
import torchvision.transforms as transforms
from torchvision.utils import save_image, make_grid
from torch.utils.data import DataLoader
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from torchvision.models import vgg19
import glob
import random
import torch
from torch.utils.data import Dataset
from PIL import Image
import time
import datetime
from torch.utils.tensorboard import SummaryWriter
import tifffile as tiff

# %% [markdown]
# # Train model

# %%
class FeatureExtractor(nn.Module):
    def __init__(self):
        super(FeatureExtractor, self).__init__()
        vgg19_model = vgg19(pretrained=True)
        self.feature_extractor = nn.Sequential(
            *list(vgg19_model.features.children())[:18]
        )

    def forward(self, img):
        return self.feature_extractor(img)


class ResidualBlock(nn.Module):
    def __init__(self, in_features):
        super(ResidualBlock, self).__init__()
        self.conv_block = nn.Sequential(
            nn.Conv2d(in_features, in_features, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_features, 0.8),
            nn.PReLU(),
            nn.Conv2d(in_features, in_features, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_features, 0.8),
        )

    def forward(self, x):
        return x + self.conv_block(x)


class GeneratorResNet(nn.Module):
    def __init__(self, in_channels=1, out_channels=1, n_residual_blocks=16):
        super(GeneratorResNet, self).__init__()

        # First layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=9, stride=1, padding=4), nn.PReLU()
        )

        # Residual blocks
        res_blocks = []
        for _ in range(n_residual_blocks):
            res_blocks.append(ResidualBlock(64))
        self.res_blocks = nn.Sequential(*res_blocks)

        # Second conv layer post residual blocks
        self.conv2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64, 0.8),
        )

        # Upsampling layers
        upsampling = []
        # 修改代码 只扩大er倍
        for out_features in range(1):
            upsampling += [
                # nn.Upsample(scale_factor=2),
                nn.Conv2d(64, 256, 3, 1, 1),
                nn.BatchNorm2d(256),
                # 尺度变换4*4 选用基于插值bicubic的Upsample替代PixelShuffle
                # nn.Upsample(scale_factor=2, mode='bicubic'),
                nn.PixelShuffle(upscale_factor=2),
                nn.PReLU(),
            ]
        self.upsampling = nn.Sequential(*upsampling)

        # Final output layer
        self.conv3 = nn.Sequential(
            nn.Conv2d(64, out_channels, kernel_size=9, stride=2, padding=4), nn.Tanh()
        )

    def forward(self, x):
        out1 = self.conv1(x)
        out = self.res_blocks(out1)
        out2 = self.conv2(out)
        out = torch.add(out1, out2)
        out = self.upsampling(out)
        out = self.conv3(out)
        return out


class C(nn.Module):
    def __init__(self, input_shape):
        super(C, self).__init__()

        self.input_shape = input_shape
        in_channels, in_height, in_width = self.input_shape
        patch_h, patch_w = int(in_height / 2**4), int(in_width / 2**4)
        self.output_shape = (1, patch_h, patch_w)

        def c_block(in_filters, out_filters, first_block=False):
            layers = []
            layers.append(
                nn.Conv2d(in_filters, out_filters, kernel_size=3, stride=1, padding=1)
            )
            if not first_block:
                layers.append(nn.BatchNorm2d(out_filters))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            layers.append(
                nn.Conv2d(out_filters, out_filters, kernel_size=3, stride=2, padding=1)
            )
            layers.append(nn.BatchNorm2d(out_filters))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        layers = []
        in_filters = in_channels
        for i, out_filters in enumerate([64, 128, 256, 512]):
            layers.extend(c_block(in_filters, out_filters, first_block=(i == 0)))
            in_filters = out_filters

        layers.append(nn.Conv2d(out_filters, 1, kernel_size=3, stride=1, padding=1))

        self.model = nn.Sequential(*layers)

    def forward(self, img):
        return self.model(img)


class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()

    def forward(self, pred, truth):
        return torch.sqrt(torch.mean((pred - truth) ** 2))
        torch.square((pred - truth) ** 2)


mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])

# %%
from PIL import Image


class ImageDataset(Dataset):
    def __init__(self, root, hr_shape, global_min=None, global_max=None):
        hr_height, hr_width = hr_shape
        self.global_min = global_min
        self.global_max = global_max
        self.lr_transform = transforms.Compose(
            [
                transforms.ToTensor(),
            ]
        )
        self.hr_transform = transforms.Compose(
            [
                transforms.ToTensor(),
            ]
        )
        self.files = sorted(glob.glob(root + "/m*.*"))

    def __getitem__(self, index):
        img = io.imread(self.files[index % len(self.files)])
        
        # Use global_min and global_max if provided, otherwise compute from image
        if self.global_min is not None and self.global_max is not None:
            min_value = self.global_min
            max_value = self.global_max
        else:
            min_value = np.min(img)
            max_value = np.max(img)
        
        # Normalize to [-1, 1] range
        abs_min_value = np.abs(min_value)
        shifted_img = img + abs_min_value
        img_ts = self.lr_transform(shifted_img)
        
        # Normalize based on global or local min/max
        range_val = (max_value + abs_min_value)
        if range_val > 0:
            img_ts = (img_ts - 0) / (133.8791 / 2) - 1
        
        w = img_ts.shape[2] // 2
        img_lr = img_ts[:, :, w:]
        img_hr = img_ts[:, :, :w]
        return {"lr": img_lr, "hr": img_hr}

    def __len__(self):
        return len(self.files)

# %%
#! pip install rasterio

# %% [markdown]
# # Make train dataset

# %% [markdown]
# ## Our original image

# %%
import rasterio
from rasterio.plot import show

fp = r"/home/s1300211/Documents/datasets/training/NAC_DTM_A17_1500.tif"
img = rasterio.open(fp)
show(img)
# Out:
# <Axes: >

# %%
img.width
# Out:
# 1500

# %%
img.height
# Out:
# 1500

# %%
img_hr = img.read()[0]

# %%
img_hr.shape
# Out:
# (1500, 1500)

# %%
# used for naormalization
min(img_hr.flatten())
# Out:
# -1310.4727

# %%
max(img_hr.flatten())
# Out:
# -1176.5936

# %% [markdown]
# ## Split image to n 64\*64 images

# %%
M, N = 64, 64
images_tiles = [
    img_hr[x : x + M, y : y + N]
    for x in range(0, img_hr.shape[0], M)
    for y in range(0, img_hr.shape[1], N)
]

# %%
# we get 676 images
len(images_tiles)
# Out:
# 576

# %%
# for i in images_tiles:
#   print(i.shape)

# %%
# save images
index = 0
for img in images_tiles:
    if img.shape == (64, 64):
        tiff.imwrite(DATASET_DIR + "/hr_" + str(index) + ".tif", img)
        index += 1

# %% [markdown]
# ## Visualization of examples from High-resolution (HR) images

# %%
for index in range(10):
    fp = r"/home/s1300211/Documents/DEM-Super-Resolution/dataset/hr_" + str(index) + ".tif"
    img = rasterio.open(fp)
    show(img)

# %% [markdown]
# ## Extract Low-resolution (LR) images from HR images

# %%
#!pip install -q condacolab
# import condacolab
# condacolab.install()
#!mamba install -q gdal=3.4.1
# from osgeo import gdal
# gdal.VersionInfo()

# %%
from scipy import ndimage
import rasterio
from rasterio.plot import show

# %%
# Count how many HR tiles were actually saved
num_hr_tiles = 0
for img in images_tiles:
    if img.shape == (64, 64):
        num_hr_tiles += 1

print(f"Processing {num_hr_tiles} HR tiles...")

for image_index in range(num_hr_tiles):
    # Use rasterio instead of GDAL
    hr_file_path = DATASET_DIR + "/hr_" + str(image_index) + ".tif"
    
    with rasterio.open(hr_file_path) as src:
        elevation_data = src.read(1)
    
    # Define the new resolution
    new_resolution = 0.5  # Example: half the resolution
    
    # Compute the new size
    original_height, original_width = elevation_data.shape
    new_height = int(original_height * new_resolution)
    new_width = int(original_width * new_resolution)
    
    # Rescale the image using nearest neighbor interpolation
    downscaled_data = np.zeros((new_height, new_width))
    for i in range(new_height):
        for j in range(new_width):
            # Calculate the corresponding pixel coordinates in the original image
            x = int(i / new_resolution)
            y = int(j / new_resolution)
            downscaled_data[i, j] = elevation_data[x, y]  # Assign the value from the nearest neighbor
    
    downsampled_dem = downscaled_data
    
    # Define the upsampling factor
    upsample_factor = 2  # Change this value as needed
    
    # Upsample the image using nearest neighbor interpolation (order=0)
    upsampled_dem = ndimage.zoom(downsampled_dem, upsample_factor, order=0)
    
    # Concatenate hr image with lr image horizontally
    image = np.concatenate((elevation_data, upsampled_dem), axis=1)
    tiff.imwrite(DATASET_DIR + "/m" + str(image_index) + ".tif", image)
    
    if (image_index + 1) % 10 == 0:
        print(f"  Processed {image_index + 1}/{num_hr_tiles} tiles")
# Out:
# Processing 529 HR tiles...
#   Processed 10/529 tiles
#   Processed 20/529 tiles
#   Processed 30/529 tiles
#   Processed 40/529 tiles
#   Processed 50/529 tiles
#   Processed 60/529 tiles
#   Processed 70/529 tiles
#   Processed 80/529 tiles
#   Processed 90/529 tiles
#   Processed 100/529 tiles
#   Processed 110/529 tiles
#   Processed 120/529 tiles
#   Processed 130/529 tiles
#   Processed 140/529 tiles
#   Processed 150/529 tiles
#   Processed 160/529 tiles
#   Processed 170/529 tiles
#   Processed 180/529 tiles
#   Processed 190/529 tiles
#   Processed 200/529 tiles
#   Processed 210/529 tiles
#   Processed 220/529 tiles
#   Processed 230/529 tiles
#   Processed 240/529 tiles
#   Processed 250/529 tiles
#   Processed 260/529 tiles
#   Processed 270/529 tiles
#   Processed 280/529 tiles
#   Processed 290/529 tiles
#   Processed 150/529 tiles
#   Processed 160/529 tiles
#   Processed 170/529 tiles
#   Processed 180/529 tiles
#   Processed 190/529 tiles
#   Processed 200/529 tiles
#   Processed 210/529 tiles
#   Processed 220/529 tiles
#   Processed 230/529 tiles
#   Processed 240/529 tiles
#   Processed 250/529 tiles
#   Processed 260/529 tiles
#   Processed 270/529 tiles
#   Processed 280/529 tiles
#   Processed 290/529 tiles
#   Processed 300/529 tiles
#   Processed 310/529 tiles
#   Processed 320/529 tiles
#   Processed 330/529 tiles
#   Processed 340/529 tiles
#   Processed 350/529 tiles
#   Processed 360/529 tiles
#   Processed 370/529 tiles
#   Processed 380/529 tiles
#   Processed 390/529 tiles
#   Processed 400/529 tiles
#   Processed 410/529 tiles
#   Processed 420/529 tiles
#   Processed 430/529 tiles
#   Processed 440/529 tiles
#   Processed 300/529 tiles
#   Processed 310/529 tiles
#   Processed 320/529 tiles
#   Processed 330/529 tiles
#   Processed 340/529 tiles
#   Processed 350/529 tiles
#   Processed 360/529 tiles
#   Processed 370/529 tiles
#   Processed 380/529 tiles
#   Processed 390/529 tiles
#   Processed 400/529 tiles
#   Processed 410/529 tiles
#   Processed 420/529 tiles
#   Processed 430/529 tiles
#   Processed 440/529 tiles
#   Processed 450/529 tiles
#   Processed 460/529 tiles
#   Processed 470/529 tiles
#   Processed 480/529 tiles
#   Processed 490/529 tiles
#   Processed 500/529 tiles
#   Processed 510/529 tiles
#   Processed 520/529 tiles
#   Processed 450/529 tiles
#   Processed 460/529 tiles
#   Processed 470/529 tiles
#   Processed 480/529 tiles
#   Processed 490/529 tiles
#   Processed 500/529 tiles
#   Processed 510/529 tiles
#   Processed 520/529 tiles

# %% [markdown]
# ## Plot examples from the dataset

# %%
for index in range(20):
    fp = r"/home/s1300211/Documents/DEM-Super-Resolution/dataset/m" + str(index) + ".tif"
    img = rasterio.open(fp)
    show(img)

# %% [markdown]
# # Train the model

# %%
DATBASE_PATH = r"/home/s1300211/Documents/DEM-Super-Resolution/dataset/"
epoch = 0  # epoch to start training from 最初なので０にしました　もとは９９です
n_epochs = 250  # number of epochs of training
batch_size = 16  # size of the batches
lr = 0.0002  # adam: learning rate
b1 = 0.5  # decay of first order momentum of gradient
b2 = 0.999  # help="adam: decay of first order momentum of gradient
decay_epoch = 100  # help="epoch from which to start lr decay
n_cpu = 0  # help="number of cpu threads to use during batch generation
hr_height = 64  # high resolution image height
hr_width = 64  # high resolution image width
channels = 1  # number of image channels
sample_interval = 100  # interval between saving image samples")
checkpoint_interval = 10  # interval between model checkpoints

# %%
# !nvidia-smi
# Out:
# 3555.78s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Mon Dec  8 12:51:18 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.163.01             Driver Version: 550.163.01     CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4090        Off |   00000000:01:00.0  On |                  Off |
# |  0%   37C    P8             45W /  450W |    5256MiB /  24564MiB |     31%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A    401963      G   /usr/lib/xorg/Xorg                           1275MiB |
# |    0   N/A  N/A    414226      G   /usr/bin/gnome-shell                          132MiB |
# |    0   N/A  N/A    416515      G   /usr/lib/thunderbird/thunderbird              245MiB |
# |    0   N/A  N/A   1594398      G   ...10,262144 --variations-seed-version         80MiB |
# |    0   N/A  N/A   1594400      G   /proc/self/exe                                162MiB |
# |    0   N/A  N/A   1594484      G   ...seed-version=20251204-170109.873000        372MiB |
# |    0   N/A  N/A   1633529      C   ...1300211/Documents/venv_2/bin/python       2954MiB |
# +-----------------------------------------------------------------------------------------+

# %%
cuda = torch.cuda.is_available()
hr_shape = (hr_height, hr_width)
generator = GeneratorResNet()
c = C(input_shape=(channels, *hr_shape))
feature_extractor = FeatureExtractor()

feature_extractor.eval()

criterion_r = RMSELoss()

criterion_content = torch.nn.L1Loss()


if cuda:
    generator = generator.cuda()
    c = c.cuda()
    feature_extractor = feature_extractor.cuda()
    criterion_r = criterion_r.cuda()
    criterion_content = criterion_content.cuda()

if epoch != 0:
    generator.load_state_dict(
        torch.load(
            "/content/drive/MyDrive/GISR_code/GISR_checkpoint/generator_120.pth",
            map_location=torch.device('cpu') # GPUが利用できない場合にCPUにマップしてロード
        )
    )

optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr, betas=(b1, b2))
optimizer_C = torch.optim.Adam(c.parameters(), lr=lr * 0.1, betas=(b1, b2))

Tensor = torch.cuda.FloatTensor if cuda else torch.Tensor

# min_valとmax_valが利用可能であることを確認し、ImageDatasetに渡してください
# 例: ImageDataset(DATBASE_PATH, hr_shape=hr_shape, global_min=min_val, global_max=max_val),
# 現在のコードではglobal_minとglobal_maxが渡されていないためエラーになる可能性があります。
# 以前の修正内容を反映することを推奨します。
# 例として、placeholderの値を入れておきますが、ご自身のDEMの正確なmin_valとmax_valに置き換えてください。
# （これらの値はコードセルの実行結果から取得できます。）

# --- Placeholder values for global_min and global_max ---
# 実際のmin_valとmax_valの値に置き換えてください
placeholder_min_val = -1289.3720703125 # fp_your_demで取得された実際の最小値
placeholder_max_val = -1185.1080322265625 # fp_your_demで取得された実際の最大値
# --------------------------------------------------------

dataloader = DataLoader(
    ImageDataset(DATBASE_PATH, hr_shape=hr_shape, global_min=placeholder_min_val, global_max=placeholder_max_val),
    batch_size=batch_size,
    shuffle=True,
    num_workers=n_cpu,
)
writer = SummaryWriter(DATBASE_PATH + "/logs")
# Out:
# /home/s1300211/Documents/venv_2/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/s1300211/Documents/venv_2/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
loss = []
for epoch in range(epoch, n_epochs):
    start = time.time()
    for i, imgs in enumerate(dataloader):

        imgs_lr = Variable(imgs["lr"].type(Tensor))
        imgs_hr = Variable(imgs["hr"].type(Tensor))

        valid = Variable(
            Tensor(np.ones((imgs_lr.size(0), *c.output_shape))), requires_grad=False
        )
        fake = Variable(
            Tensor(np.zeros((imgs_lr.size(0), *c.output_shape))), requires_grad=False
        )

        # -------------------
        #  Train Generator
        # -------------------

        optimizer_G.zero_grad()

        gen_hr = generator(imgs_lr)
        gen_hr = (gen_hr + imgs_lr) / 2

        # GANの要素を減らすために loss_r の重みを0にする (または非常に小さい値)
        # 知覚損失の要素を減らすために loss_content の重みも0にする (または非常に小さい値)
        loss_r = criterion_r(c(gen_hr), valid) * 0 # GAN要素を無効化

        real_dem_3c = torch.cat((imgs_hr, imgs_hr, imgs_hr), 1)
        gen_dem_3c = torch.cat((gen_hr, gen_hr, gen_hr), 1)
        gen_features = feature_extractor(gen_dem_3c)
        real_features = feature_extractor(real_dem_3c)
        loss_content = criterion_content(gen_features, real_features.detach()) * 0 # 知覚損失を無効化

        loss_RMSE = criterion_r(imgs_hr, gen_hr)

        # loss_G を再定義し、RMSE損失のみを強調する (または他の損失の重みを減らす)
        loss_G = loss_content + loss_r + 10 * loss_RMSE # loss_contentとloss_rは0になる

        loss_G.backward()
        optimizer_G.step()

        # ---------------------
        #  Train Discriminator
        # ---------------------

        # loss_r の重みが0の場合、Discriminatorの学習はGeneratorに影響しませんが、
        # コードの整合性を保つため、学習プロセスは残します。
        optimizer_C.zero_grad()

        # Real images
        loss_real = criterion_r(c(imgs_hr), valid)
        # Fake images
        loss_fake = criterion_r(c(gen_hr.detach()), fake)

        # Total Discriminator loss
        loss_C = (loss_real + loss_fake) / 2

        if i % 3 == 0:
            loss_C.backward()
            optimizer_C.step()

        sys.stdout.write(
            "[Epoch %d/%d] [Batch %d/%d]  [G loss: %f]"
            % (epoch, n_epochs, i, len(dataloader), loss_G.item())
        )
        batches_done = epoch * len(dataloader) + i
        if batches_done % sample_interval == 0:
            gen_hr = make_grid(gen_hr, nrow=1, normalize=True)
            imgs_lr = make_grid(imgs_lr, nrow=1, normalize=True)
            imgs_hr = make_grid(imgs_hr, nrow=1, normalize=True)
            writer.add_scalar("loss_G", loss_G.item(), batches_done)
            writer.add_scalar("loss_RMSE", loss_RMSE.item(), batches_done)
            img_grid = torch.cat((imgs_lr, gen_hr, imgs_hr), -1)
            save_image(
                img_grid, DATBASE_PATH + "/%d.png" % batches_done, normalize=False
            )
    print("Time taken for epoch {} is {} sec\n".format(epoch + 1, time.time() - start))
    loss.append(loss_G)
    if checkpoint_interval != -1 and epoch % checkpoint_interval == 0:
        # Save model checkpoints
        torch.save(
            generator.state_dict(),
            "/home/s1300211/Documents/DEM-Super-Resolution/models/generator_%d.pth" % epoch,
        )
# Out:
# [Epoch 0/250] [Batch 0/34]  [G loss: 3.980583][Epoch 0/250] [Batch 1/34]  [G loss: 2.581688][Epoch 0/250] [Batch 2/34]  [G loss: 2.510190][Epoch 0/250] [Batch 3/34]  [G loss: 1.618230][Epoch 0/250] [Batch 4/34]  [G loss: 2.794979][Epoch 0/250] [Batch 5/34]  [G loss: 1.329054][Epoch 0/250] [Batch 6/34]  [G loss: 2.730527][Epoch 0/250] [Batch 7/34]  [G loss: 1.050877][Epoch 0/250] [Batch 8/34]  [G loss: 1.319355][Epoch 0/250] [Batch 9/34]  [G loss: 1.052892][Epoch 0/250] [Batch 5/34]  [G loss: 1.329054][Epoch 0/250] [Batch 6/34]  [G loss: 2.730527][Epoch 0/250] [Batch 7/34]  [G loss: 1.050877][Epoch 0/250] [Batch 8/34]  [G loss: 1.319355][Epoch 0/250] [Batch 9/34]  [G loss: 1.052892][Epoch 0/250] [Batch 10/34]  [G loss: 1.808625][Epoch 0/250] [Batch 11/34]  [G loss: 1.111236][Epoch 0/250] [Batch 12/34]  [G loss: 1.011359][Epoch 0/250] [Batch 13/34]  [G loss: 2.590134][Epoch 0/250] [Batch 14/34]  [G loss: 1.393004][Epoch 0/250] [Batch 15/34]  [G loss: 2.289510][Epoch 0/250] [Batch 10/34]  [G loss: 1.808625][Epoch 0/250] [Batch 11/34]  [G loss: 1.111236][Epoch 0/250] [Batch 12/34]  [G loss: 1.011359][Epoch 0/250] [Batch 13/34]  [G loss: 2.590134][Epoch 0/250] [Batch 14/34]  [G loss: 1.393004][Epoch 0/250] [Batch 15/34]  [G loss: 2.289510][Epoch 0/250] [Batch 16/34]  [G loss: 3.520386][Epoch 0/250] [Batch 17/34]  [G loss: 1.061809][Epoch 0/250] [Batch 18/34]  [G loss: 1.370393][Epoch 0/250] [Batch 19/34]  [G loss: 2.342448][Epoch 0/250] [Batch 20/34]  [G loss: 1.658605][Epoch 0/250] [Batch 21/34]  [G loss: 1.025575][Epoch 0/250] [Batch 16/34]  [G loss: 3.520386][Epoch 0/250] [Batch 17/34]  [G loss: 1.061809][Epoch 0/250] [Batch 18/34]  [G loss: 1.370393][Epoch 0/250] [Batch 19/34]  [G loss: 2.342448][Epoch 0/250] [Batch 20/34]  [G loss: 1.658605][Epoch 0/250] [Batch 21/34]  [G loss: 1.025575][Epoch 0/250] [Batch 22/34]  [G loss: 0.646652][Epoch 0/250] [Batch 23/34]  [G loss: 1.951217][Epoch 0/250] [Batch 24/34]  [G loss: 1.434141][Epoch 0/250] [Batch 25/34]  [G loss: 2.385219][Epoch 0/250] [Batch 26/34]  [G loss: 0.748290][Epoch 0/250] [Batch 22/34]  [G loss: 0.646652][Epoch 0/250] [Batch 23/34]  [G loss: 1.951217][Epoch 0/250] [Batch 24/34]  [G loss: 1.434141][Epoch 0/250] [Batch 25/34]  [G loss: 2.385219][Epoch 0/250] [Batch 26/34]  [G loss: 0.748290][Epoch 0/250] [Batch 27/34]  [G loss: 1.398861][Epoch 0/250] [Batch 28/34]  [G loss: 2.803952][Epoch 0/250] [Batch 29/34]  [G loss: 1.485900][Epoch 0/250] [Batch 30/34]  [G loss: 0.729315][Epoch 0/250] [Batch 31/34]  [G loss: 0.962982][Epoch 0/250] [Batch 27/34]  [G loss: 1.398861][Epoch 0/250] [Batch 28/34]  [G loss: 2.803952][Epoch 0/250] [Batch 29/34]  [G loss: 1.485900][Epoch 0/250] [Batch 30/34]  [G loss: 0.729315][Epoch 0/250] [Batch 31/34]  [G loss: 0.962982][Epoch 0/250] [Batch 32/34]  [G loss: 0.916148][Epoch 0/250] [Batch 33/34]  [G loss: 0.754743]Time taken for epoch 1 is 1.369178056716919 sec
#
# [Epoch 1/250] [Batch 0/34]  [G loss: 0.659480][Epoch 1/250] [Batch 1/34]  [G loss: 1.148536][Epoch 1/250] [Batch 2/34]  [G loss: 0.733749][Epoch 1/250] [Batch 3/34]  [G loss: 0.742541][Epoch 0/250] [Batch 32/34]  [G loss: 0.916148][Epoch 0/250] [Batch 33/34]  [G loss: 0.754743]Time taken for epoch 1 is 1.369178056716919 sec
#
# [Epoch 1/250] [Batch 0/34]  [G loss: 0.659480][Epoch 1/250] [Batch 1/34]  [G loss: 1.148536][Epoch 1/250] [Batch 2/34]  [G loss: 0.733749][Epoch 1/250] [Batch 3/34]  [G loss: 0.742541][Epoch 1/250] [Batch 4/34]  [G loss: 0.706066][Epoch 1/250] [Batch 5/34]  [G loss: 0.430201][Epoch 1/250] [Batch 6/34]  [G loss: 0.774198][Epoch 1/250] [Batch 7/34]  [G loss: 0.387999][Epoch 1/250] [Batch 8/34]  [G loss: 0.292232][Epoch 1/250] [Batch 9/34]  [G loss: 0.361257][Epoch 1/250] [Batch 4/34]  [G loss: 0.706066][Epoch 1/250] [Batch 5/34]  [G loss: 0.430201][Epoch 1/250] [Batch 6/34]  [G loss: 0.774198][Epoch 1/250] [Batch 7/34]  [G loss: 0.387999][Epoch 1/250] [Batch 8/34]  [G loss: 0.292232][Epoch 1/250] [Batch 9/34]  [G loss: 0.361257][Epoch 1/250] [Batch 10/34]  [G loss: 0.770151][Epoch 1/250] [Batch 11/34]  [G loss: 0.448304][Epoch 1/250] [Batch 12/34]  [G loss: 0.227367][Epoch 1/250] [Batch 13/34]  [G loss: 1.007422][Epoch 1/250] [Batch 14/34]  [G loss: 0.343818][Epoch 1/250] [Batch 15/34]  [G loss: 0.509667][Epoch 1/250] [Batch 10/34]  [G loss: 0.770151][Epoch 1/250] [Batch 11/34]  [G loss: 0.448304][Epoch 1/250] [Batch 12/34]  [G loss: 0.227367][Epoch 1/250] [Batch 13/34]  [G loss: 1.007422][Epoch 1/250] [Batch 14/34]  [G loss: 0.343818][Epoch 1/250] [Batch 15/34]  [G loss: 0.509667][Epoch 1/250] [Batch 16/34]  [G loss: 0.745226][Epoch 1/250] [Batch 17/34]  [G loss: 0.657976][Epoch 1/250] [Batch 18/34]  [G loss: 1.096209][Epoch 1/250] [Batch 19/34]  [G loss: 0.630868][Epoch 1/250] [Batch 20/34]  [G loss: 0.534983][Epoch 1/250] [Batch 21/34]  [G loss: 0.626099][Epoch 1/250] [Batch 16/34]  [G loss: 0.745226][Epoch 1/250] [Batch 17/34]  [G loss: 0.657976][Epoch 1/250] [Batch 18/34]  [G loss: 1.096209][Epoch 1/250] [Batch 19/34]  [G loss: 0.630868][Epoch 1/250] [Batch 20/34]  [G loss: 0.534983][Epoch 1/250] [Batch 21/34]  [G loss: 0.626099][Epoch 1/250] [Batch 22/34]  [G loss: 0.782683][Epoch 1/250] [Batch 23/34]  [G loss: 0.417940][Epoch 1/250] [Batch 24/34]  [G loss: 1.184326][Epoch 1/250] [Batch 25/34]  [G loss: 0.705617][Epoch 1/250] [Batch 26/34]  [G loss: 0.549490][Epoch 1/250] [Batch 27/34]  [G loss: 0.542289][Epoch 1/250] [Batch 22/34]  [G loss: 0.782683][Epoch 1/250] [Batch 23/34]  [G loss: 0.417940][Epoch 1/250] [Batch 24/34]  [G loss: 1.184326][Epoch 1/250] [Batch 25/34]  [G loss: 0.705617][Epoch 1/250] [Batch 26/34]  [G loss: 0.549490][Epoch 1/250] [Batch 27/34]  [G loss: 0.542289][Epoch 1/250] [Batch 28/34]  [G loss: 0.515518][Epoch 1/250] [Batch 29/34]  [G loss: 0.561633][Epoch 1/250] [Batch 30/34]  [G loss: 0.479037][Epoch 1/250] [Batch 31/34]  [G loss: 0.512079][Epoch 1/250] [Batch 32/34]  [G loss: 0.422068][Epoch 1/250] [Batch 33/34]  [G loss: 0.785740]Time taken for epoch 2 is 1.31575608253479 sec
#
# [Epoch 1/250] [Batch 28/34]  [G loss: 0.515518][Epoch 1/250] [Batch 29/34]  [G loss: 0.561633][Epoch 1/250] [Batch 30/34]  [G loss: 0.479037][Epoch 1/250] [Batch 31/34]  [G loss: 0.512079][Epoch 1/250] [Batch 32/34]  [G loss: 0.422068][Epoch 1/250] [Batch 33/34]  [G loss: 0.785740]Time taken for epoch 2 is 1.31575608253479 sec
#
# [Epoch 2/250] [Batch 0/34]  [G loss: 0.412581][Epoch 2/250] [Batch 1/34]  [G loss: 0.397064][Epoch 2/250] [Batch 2/34]  [G loss: 0.264763][Epoch 2/250] [Batch 3/34]  [G loss: 0.377128][Epoch 2/250] [Batch 4/34]  [G loss: 0.363851][Epoch 2/250] [Batch 5/34]  [G loss: 0.419792][Epoch 2/250] [Batch 0/34]  [G loss: 0.412581][Epoch 2/250] [Batch 1/34]  [G loss: 0.397064][Epoch 2/250] [Batch 2/34]  [G loss: 0.264763][Epoch 2/250] [Batch 3/34]  [G loss: 0.377128][Epoch 2/250] [Batch 4/34]  [G loss: 0.363851][Epoch 2/250] [Batch 5/34]  [G loss: 0.419792][Epoch 2/250] [Batch 6/34]  [G loss: 0.698717][Epoch 2/250] [Batch 7/34]  [G loss: 1.025762][Epoch 2/250] [Batch 8/34]  [G loss: 0.581498][Epoch 2/250] [Batch 9/34]  [G loss: 0.486765][Epoch 2/250] [Batch 10/34]  [G loss: 0.373854][Epoch 2/250] [Batch 11/34]  [G loss: 0.340487][Epoch 2/250] [Batch 6/34]  [G loss: 0.698717][Epoch 2/250] [Batch 7/34]  [G loss: 1.025762][Epoch 2/250] [Batch 8/34]  [G loss: 0.581498][Epoch 2/250] [Batch 9/34]  [G loss: 0.486765][Epoch 2/250] [Batch 10/34]  [G loss: 0.373854][Epoch 2/250] [Batch 11/34]  [G loss: 0.340487][Epoch 2/250] [Batch 12/34]  [G loss: 0.605328][Epoch 2/250] [Batch 13/34]  [G loss: 1.274755][Epoch 2/250] [Batch 14/34]  [G loss: 0.526259][Epoch 2/250] [Batch 15/34]  [G loss: 0.217911][Epoch 2/250] [Batch 16/34]  [G loss: 0.405128][Epoch 2/250] [Batch 17/34]  [G loss: 1.184680][Epoch 2/250] [Batch 12/34]  [G loss: 0.605328][Epoch 2/250] [Batch 13/34]  [G loss: 1.274755][Epoch 2/250] [Batch 14/34]  [G loss: 0.526259][Epoch 2/250] [Batch 15/34]  [G loss: 0.217911][Epoch 2/250] [Batch 16/34]  [G loss: 0.405128][Epoch 2/250] [Batch 17/34]  [G loss: 1.184680][Epoch 2/250] [Batch 18/34]  [G loss: 0.619298][Epoch 2/250] [Batch 19/34]  [G loss: 0.391123][Epoch 2/250] [Batch 20/34]  [G loss: 0.530502][Epoch 2/250] [Batch 21/34]  [G loss: 0.507343][Epoch 2/250] [Batch 22/34]  [G loss: 0.308772][Epoch 2/250] [Batch 23/34]  [G loss: 0.243073][Epoch 2/250] [Batch 18/34]  [G loss: 0.619298][Epoch 2/250] [Batch 19/34]  [G loss: 0.391123][Epoch 2/250] [Batch 20/34]  [G loss: 0.530502][Epoch 2/250] [Batch 21/34]  [G loss: 0.507343][Epoch 2/250] [Batch 22/34]  [G loss: 0.308772][Epoch 2/250] [Batch 23/34]  [G loss: 0.243073][Epoch 2/250] [Batch 24/34]  [G loss: 1.031493][Epoch 2/250] [Batch 25/34]  [G loss: 0.854355][Epoch 2/250] [Batch 26/34]  [G loss: 0.971071][Epoch 2/250] [Batch 27/34]  [G loss: 0.568579][Epoch 2/250] [Batch 28/34]  [G loss: 0.526125][Epoch 2/250] [Batch 29/34]  [G loss: 0.851977][Epoch 2/250] [Batch 24/34]  [G loss: 1.031493][Epoch 2/250] [Batch 25/34]  [G loss: 0.854355][Epoch 2/250] [Batch 26/34]  [G loss: 0.971071][Epoch 2/250] [Batch 27/34]  [G loss: 0.568579][Epoch 2/250] [Batch 28/34]  [G loss: 0.526125][Epoch 2/250] [Batch 29/34]  [G loss: 0.851977][Epoch 2/250] [Batch 30/34]  [G loss: 0.603787][Epoch 2/250] [Batch 31/34]  [G loss: 1.001204][Epoch 2/250] [Batch 32/34]  [G loss: 0.911151][Epoch 2/250] [Batch 33/34]  [G loss: 0.561438]Time taken for epoch 3 is 1.3338065147399902 sec
#
# [Epoch 3/250] [Batch 0/34]  [G loss: 0.692200][Epoch 3/250] [Batch 1/34]  [G loss: 0.655301][Epoch 2/250] [Batch 30/34]  [G loss: 0.603787][Epoch 2/250] [Batch 31/34]  [G loss: 1.001204][Epoch 2/250] [Batch 32/34]  [G loss: 0.911151][Epoch 2/250] [Batch 33/34]  [G loss: 0.561438]Time taken for epoch 3 is 1.3338065147399902 sec
#
# [Epoch 3/250] [Batch 0/34]  [G loss: 0.692200][Epoch 3/250] [Batch 1/34]  [G loss: 0.655301][Epoch 3/250] [Batch 2/34]  [G loss: 0.493240][Epoch 3/250] [Batch 3/34]  [G loss: 0.549167][Epoch 3/250] [Batch 4/34]  [G loss: 0.694956][Epoch 3/250] [Batch 5/34]  [G loss: 0.333165][Epoch 3/250] [Batch 6/34]  [G loss: 0.687221][Epoch 3/250] [Batch 7/34]  [G loss: 0.685716][Epoch 3/250] [Batch 2/34]  [G loss: 0.493240][Epoch 3/250] [Batch 3/34]  [G loss: 0.549167][Epoch 3/250] [Batch 4/34]  [G loss: 0.694956][Epoch 3/250] [Batch 5/34]  [G loss: 0.333165][Epoch 3/250] [Batch 6/34]  [G loss: 0.687221][Epoch 3/250] [Batch 7/34]  [G loss: 0.685716][Epoch 3/250] [Batch 8/34]  [G loss: 0.978940][Epoch 3/250] [Batch 9/34]  [G loss: 0.652567][Epoch 3/250] [Batch 10/34]  [G loss: 0.736195][Epoch 3/250] [Batch 11/34]  [G loss: 0.337435][Epoch 3/250] [Batch 12/34]  [G loss: 0.582753][Epoch 3/250] [Batch 8/34]  [G loss: 0.978940][Epoch 3/250] [Batch 9/34]  [G loss: 0.652567][Epoch 3/250] [Batch 10/34]  [G loss: 0.736195][Epoch 3/250] [Batch 11/34]  [G loss: 0.337435][Epoch 3/250] [Batch 12/34]  [G loss: 0.582753][Epoch 3/250] [Batch 13/34]  [G loss: 0.442877][Epoch 3/250] [Batch 14/34]  [G loss: 0.298063][Epoch 3/250] [Batch 15/34]  [G loss: 0.417483][Epoch 3/250] [Batch 16/34]  [G loss: 0.564518][Epoch 3/250] [Batch 17/34]  [G loss: 0.210222][Epoch 3/250] [Batch 18/34]  [G loss: 0.471295][Epoch 3/250] [Batch 13/34]  [G loss: 0.442877][Epoch 3/250] [Batch 14/34]  [G loss: 0.298063][Epoch 3/250] [Batch 15/34]  [G loss: 0.417483][Epoch 3/250] [Batch 16/34]  [G loss: 0.564518][Epoch 3/250] [Batch 17/34]  [G loss: 0.210222][Epoch 3/250] [Batch 18/34]  [G loss: 0.471295][Epoch 3/250] [Batch 19/34]  [G loss: 0.916037][Epoch 3/250] [Batch 20/34]  [G loss: 0.555759][Epoch 3/250] [Batch 21/34]  [G loss: 0.563437][Epoch 3/250] [Batch 22/34]  [G loss: 0.254622][Epoch 3/250] [Batch 23/34]  [G loss: 0.605946][Epoch 3/250] [Batch 24/34]  [G loss: 0.941729][Epoch 3/250] [Batch 19/34]  [G loss: 0.916037][Epoch 3/250] [Batch 20/34]  [G loss: 0.555759][Epoch 3/250] [Batch 21/34]  [G loss: 0.563437][Epoch 3/250] [Batch 22/34]  [G loss: 0.254622][Epoch 3/250] [Batch 23/34]  [G loss: 0.605946][Epoch 3/250] [Batch 24/34]  [G loss: 0.941729][Epoch 3/250] [Batch 25/34]  [G loss: 0.546562][Epoch 3/250] [Batch 26/34]  [G loss: 0.643439][Epoch 3/250] [Batch 27/34]  [G loss: 0.573065][Epoch 3/250] [Batch 28/34]  [G loss: 1.180293][Epoch 3/250] [Batch 29/34]  [G loss: 0.394630][Epoch 3/250] [Batch 30/34]  [G loss: 0.380400][Epoch 3/250] [Batch 25/34]  [G loss: 0.546562][Epoch 3/250] [Batch 26/34]  [G loss: 0.643439][Epoch 3/250] [Batch 27/34]  [G loss: 0.573065][Epoch 3/250] [Batch 28/34]  [G loss: 1.180293][Epoch 3/250] [Batch 29/34]  [G loss: 0.394630][Epoch 3/250] [Batch 30/34]  [G loss: 0.380400][Epoch 3/250] [Batch 31/34]  [G loss: 0.586292][Epoch 3/250] [Batch 32/34]  [G loss: 0.366548][Epoch 3/250] [Batch 33/34]  [G loss: 0.667953]Time taken for epoch 4 is 1.3166112899780273 sec
#
# [Epoch 4/250] [Batch 0/34]  [G loss: 1.132653][Epoch 4/250] [Batch 1/34]  [G loss: 0.880011][Epoch 4/250] [Batch 2/34]  [G loss: 1.227222][Epoch 3/250] [Batch 31/34]  [G loss: 0.586292][Epoch 3/250] [Batch 32/34]  [G loss: 0.366548][Epoch 3/250] [Batch 33/34]  [G loss: 0.667953]Time taken for epoch 4 is 1.3166112899780273 sec
#
# [Epoch 4/250] [Batch 0/34]  [G loss: 1.132653][Epoch 4/250] [Batch 1/34]  [G loss: 0.880011][Epoch 4/250] [Batch 2/34]  [G loss: 1.227222][Epoch 4/250] [Batch 3/34]  [G loss: 1.084034][Epoch 4/250] [Batch 4/34]  [G loss: 0.290460][Epoch 4/250] [Batch 5/34]  [G loss: 0.252099][Epoch 4/250] [Batch 6/34]  [G loss: 0.565684][Epoch 4/250] [Batch 7/34]  [G loss: 0.513000][Epoch 4/250] [Batch 8/34]  [G loss: 0.285830][Epoch 4/250] [Batch 3/34]  [G loss: 1.084034][Epoch 4/250] [Batch 4/34]  [G loss: 0.290460][Epoch 4/250] [Batch 5/34]  [G loss: 0.252099][Epoch 4/250] [Batch 6/34]  [G loss: 0.565684][Epoch 4/250] [Batch 7/34]  [G loss: 0.513000][Epoch 4/250] [Batch 8/34]  [G loss: 0.285830][Epoch 4/250] [Batch 9/34]  [G loss: 0.391543][Epoch 4/250] [Batch 10/34]  [G loss: 0.320937][Epoch 4/250] [Batch 11/34]  [G loss: 0.396695][Epoch 4/250] [Batch 12/34]  [G loss: 0.423145][Epoch 4/250] [Batch 13/34]  [G loss: 0.350988][Epoch 4/250] [Batch 14/34]  [G loss: 0.378531][Epoch 4/250] [Batch 9/34]  [G loss: 0.391543][Epoch 4/250] [Batch 10/34]  [G loss: 0.320937][Epoch 4/250] [Batch 11/34]  [G loss: 0.396695][Epoch 4/250] [Batch 12/34]  [G loss: 0.423145][Epoch 4/250] [Batch 13/34]  [G loss: 0.350988][Epoch 4/250] [Batch 14/34]  [G loss: 0.378531][Epoch 4/250] [Batch 15/34]  [G loss: 0.778969][Epoch 4/250] [Batch 16/34]  [G loss: 0.265461][Epoch 4/250] [Batch 17/34]  [G loss: 0.481148][Epoch 4/250] [Batch 18/34]  [G loss: 0.424911][Epoch 4/250] [Batch 19/34]  [G loss: 0.893935][Epoch 4/250] [Batch 20/34]  [G loss: 0.297545][Epoch 4/250] [Batch 15/34]  [G loss: 0.778969][Epoch 4/250] [Batch 16/34]  [G loss: 0.265461][Epoch 4/250] [Batch 17/34]  [G loss: 0.481148][Epoch 4/250] [Batch 18/34]  [G loss: 0.424911][Epoch 4/250] [Batch 19/34]  [G loss: 0.893935][Epoch 4/250] [Batch 20/34]  [G loss: 0.297545][Epoch 4/250] [Batch 21/34]  [G loss: 0.413547][Epoch 4/250] [Batch 22/34]  [G loss: 0.601194][Epoch 4/250] [Batch 23/34]  [G loss: 0.628083][Epoch 4/250] [Batch 24/34]  [G loss: 0.489240][Epoch 4/250] [Batch 25/34]  [G loss: 0.495456][Epoch 4/250] [Batch 21/34]  [G loss: 0.413547][Epoch 4/250] [Batch 22/34]  [G loss: 0.601194][Epoch 4/250] [Batch 23/34]  [G loss: 0.628083][Epoch 4/250] [Batch 24/34]  [G loss: 0.489240][Epoch 4/250] [Batch 25/34]  [G loss: 0.495456][Epoch 4/250] [Batch 26/34]  [G loss: 0.538964][Epoch 4/250] [Batch 27/34]  [G loss: 0.303479][Epoch 4/250] [Batch 28/34]  [G loss: 0.337401][Epoch 4/250] [Batch 29/34]  [G loss: 0.529794][Epoch 4/250] [Batch 30/34]  [G loss: 0.326499][Epoch 4/250] [Batch 26/34]  [G loss: 0.538964][Epoch 4/250] [Batch 27/34]  [G loss: 0.303479][Epoch 4/250] [Batch 28/34]  [G loss: 0.337401][Epoch 4/250] [Batch 29/34]  [G loss: 0.529794][Epoch 4/250] [Batch 30/34]  [G loss: 0.326499][Epoch 4/250] [Batch 31/34]  [G loss: 0.332491][Epoch 4/250] [Batch 32/34]  [G loss: 0.429385][Epoch 4/250] [Batch 33/34]  [G loss: 0.828058]Time taken for epoch 5 is 1.331402063369751 sec
#
# [Epoch 5/250] [Batch 0/34]  [G loss: 0.582258][Epoch 5/250] [Batch 1/34]  [G loss: 0.283838][Epoch 5/250] [Batch 2/34]  [G loss: 0.494980][Epoch 4/250] [Batch 31/34]  [G loss: 0.332491][Epoch 4/250] [Batch 32/34]  [G loss: 0.429385][Epoch 4/250] [Batch 33/34]  [G loss: 0.828058]Time taken for epoch 5 is 1.331402063369751 sec
#
# [Epoch 5/250] [Batch 0/34]  [G loss: 0.582258][Epoch 5/250] [Batch 1/34]  [G loss: 0.283838][Epoch 5/250] [Batch 2/34]  [G loss: 0.494980][Epoch 5/250] [Batch 3/34]  [G loss: 0.912805][Epoch 5/250] [Batch 4/34]  [G loss: 0.319578][Epoch 5/250] [Batch 5/34]  [G loss: 1.273190][Epoch 5/250] [Batch 6/34]  [G loss: 0.423646][Epoch 5/250] [Batch 7/34]  [G loss: 0.385846][Epoch 5/250] [Batch 8/34]  [G loss: 0.619144][Epoch 5/250] [Batch 3/34]  [G loss: 0.912805][Epoch 5/250] [Batch 4/34]  [G loss: 0.319578][Epoch 5/250] [Batch 5/34]  [G loss: 1.273190][Epoch 5/250] [Batch 6/34]  [G loss: 0.423646][Epoch 5/250] [Batch 7/34]  [G loss: 0.385846][Epoch 5/250] [Batch 8/34]  [G loss: 0.619144][Epoch 5/250] [Batch 9/34]  [G loss: 0.629258][Epoch 5/250] [Batch 10/34]  [G loss: 0.716908][Epoch 5/250] [Batch 11/34]  [G loss: 0.553024][Epoch 5/250] [Batch 12/34]  [G loss: 0.249440][Epoch 5/250] [Batch 13/34]  [G loss: 2.252171][Epoch 5/250] [Batch 14/34]  [G loss: 0.565174][Epoch 5/250] [Batch 9/34]  [G loss: 0.629258][Epoch 5/250] [Batch 10/34]  [G loss: 0.716908][Epoch 5/250] [Batch 11/34]  [G loss: 0.553024][Epoch 5/250] [Batch 12/34]  [G loss: 0.249440][Epoch 5/250] [Batch 13/34]  [G loss: 2.252171][Epoch 5/250] [Batch 14/34]  [G loss: 0.565174][Epoch 5/250] [Batch 15/34]  [G loss: 0.687090][Epoch 5/250] [Batch 16/34]  [G loss: 2.227621][Epoch 5/250] [Batch 17/34]  [G loss: 0.438193][Epoch 5/250] [Batch 18/34]  [G loss: 0.397812][Epoch 5/250] [Batch 19/34]  [G loss: 0.505719][Epoch 5/250] [Batch 20/34]  [G loss: 0.376714][Epoch 5/250] [Batch 15/34]  [G loss: 0.687090][Epoch 5/250] [Batch 16/34]  [G loss: 2.227621][Epoch 5/250] [Batch 17/34]  [G loss: 0.438193][Epoch 5/250] [Batch 18/34]  [G loss: 0.397812][Epoch 5/250] [Batch 19/34]  [G loss: 0.505719][Epoch 5/250] [Batch 20/34]  [G loss: 0.376714][Epoch 5/250] [Batch 21/34]  [G loss: 0.294728][Epoch 5/250] [Batch 22/34]  [G loss: 0.963948][Epoch 5/250] [Batch 23/34]  [G loss: 0.225752][Epoch 5/250] [Batch 24/34]  [G loss: 0.903186][Epoch 5/250] [Batch 25/34]  [G loss: 0.650436][Epoch 5/250] [Batch 26/34]  [G loss: 0.456438][Epoch 5/250] [Batch 21/34]  [G loss: 0.294728][Epoch 5/250] [Batch 22/34]  [G loss: 0.963948][Epoch 5/250] [Batch 23/34]  [G loss: 0.225752][Epoch 5/250] [Batch 24/34]  [G loss: 0.903186][Epoch 5/250] [Batch 25/34]  [G loss: 0.650436][Epoch 5/250] [Batch 26/34]  [G loss: 0.456438][Epoch 5/250] [Batch 27/34]  [G loss: 0.371042][Epoch 5/250] [Batch 28/34]  [G loss: 0.481195][Epoch 5/250] [Batch 29/34]  [G loss: 0.379356][Epoch 5/250] [Batch 30/34]  [G loss: 0.486149][Epoch 5/250] [Batch 31/34]  [G loss: 0.585301][Epoch 5/250] [Batch 27/34]  [G loss: 0.371042][Epoch 5/250] [Batch 28/34]  [G loss: 0.481195][Epoch 5/250] [Batch 29/34]  [G loss: 0.379356][Epoch 5/250] [Batch 30/34]  [G loss: 0.486149][Epoch 5/250] [Batch 31/34]  [G loss: 0.585301][Epoch 5/250] [Batch 32/34]  [G loss: 0.927964][Epoch 5/250] [Batch 33/34]  [G loss: 2.688491]Time taken for epoch 6 is 1.3393878936767578 sec
#
# [Epoch 6/250] [Batch 0/34]  [G loss: 0.526031][Epoch 6/250] [Batch 1/34]  [G loss: 1.061435][Epoch 6/250] [Batch 2/34]  [G loss: 0.550974][Epoch 6/250] [Batch 3/34]  [G loss: 0.397051][Epoch 5/250] [Batch 32/34]  [G loss: 0.927964][Epoch 5/250] [Batch 33/34]  [G loss: 2.688491]Time taken for epoch 6 is 1.3393878936767578 sec
#
# [Epoch 6/250] [Batch 0/34]  [G loss: 0.526031][Epoch 6/250] [Batch 1/34]  [G loss: 1.061435][Epoch 6/250] [Batch 2/34]  [G loss: 0.550974][Epoch 6/250] [Batch 3/34]  [G loss: 0.397051][Epoch 6/250] [Batch 4/34]  [G loss: 0.591601][Epoch 6/250] [Batch 5/34]  [G loss: 0.434116][Epoch 6/250] [Batch 6/34]  [G loss: 0.442641][Epoch 6/250] [Batch 7/34]  [G loss: 0.593467][Epoch 6/250] [Batch 8/34]  [G loss: 0.313842][Epoch 6/250] [Batch 9/34]  [G loss: 0.356393][Epoch 6/250] [Batch 4/34]  [G loss: 0.591601][Epoch 6/250] [Batch 5/34]  [G loss: 0.434116][Epoch 6/250] [Batch 6/34]  [G loss: 0.442641][Epoch 6/250] [Batch 7/34]  [G loss: 0.593467][Epoch 6/250] [Batch 8/34]  [G loss: 0.313842][Epoch 6/250] [Batch 9/34]  [G loss: 0.356393][Epoch 6/250] [Batch 10/34]  [G loss: 0.628115][Epoch 6/250] [Batch 11/34]  [G loss: 0.254552][Epoch 6/250] [Batch 12/34]  [G loss: 0.239401][Epoch 6/250] [Batch 13/34]  [G loss: 0.810038][Epoch 6/250] [Batch 14/34]  [G loss: 0.428183][Epoch 6/250] [Batch 15/34]  [G loss: 0.400506][Epoch 6/250] [Batch 10/34]  [G loss: 0.628115][Epoch 6/250] [Batch 11/34]  [G loss: 0.254552][Epoch 6/250] [Batch 12/34]  [G loss: 0.239401][Epoch 6/250] [Batch 13/34]  [G loss: 0.810038][Epoch 6/250] [Batch 14/34]  [G loss: 0.428183][Epoch 6/250] [Batch 15/34]  [G loss: 0.400506][Epoch 6/250] [Batch 16/34]  [G loss: 0.821702][Epoch 6/250] [Batch 17/34]  [G loss: 1.015890][Epoch 6/250] [Batch 18/34]  [G loss: 0.414526][Epoch 6/250] [Batch 19/34]  [G loss: 0.268443][Epoch 6/250] [Batch 20/34]  [G loss: 0.607435][Epoch 6/250] [Batch 21/34]  [G loss: 0.812083][Epoch 6/250] [Batch 16/34]  [G loss: 0.821702][Epoch 6/250] [Batch 17/34]  [G loss: 1.015890][Epoch 6/250] [Batch 18/34]  [G loss: 0.414526][Epoch 6/250] [Batch 19/34]  [G loss: 0.268443][Epoch 6/250] [Batch 20/34]  [G loss: 0.607435][Epoch 6/250] [Batch 21/34]  [G loss: 0.812083][Epoch 6/250] [Batch 22/34]  [G loss: 0.278123][Epoch 6/250] [Batch 23/34]  [G loss: 0.179763][Epoch 6/250] [Batch 24/34]  [G loss: 0.373127][Epoch 6/250] [Batch 25/34]  [G loss: 0.346489][Epoch 6/250] [Batch 26/34]  [G loss: 0.640358][Epoch 6/250] [Batch 27/34]  [G loss: 1.463659][Epoch 6/250] [Batch 22/34]  [G loss: 0.278123][Epoch 6/250] [Batch 23/34]  [G loss: 0.179763][Epoch 6/250] [Batch 24/34]  [G loss: 0.373127][Epoch 6/250] [Batch 25/34]  [G loss: 0.346489][Epoch 6/250] [Batch 26/34]  [G loss: 0.640358][Epoch 6/250] [Batch 27/34]  [G loss: 1.463659][Epoch 6/250] [Batch 28/34]  [G loss: 0.465280][Epoch 6/250] [Batch 29/34]  [G loss: 0.361698][Epoch 6/250] [Batch 30/34]  [G loss: 0.308075][Epoch 6/250] [Batch 31/34]  [G loss: 0.631471][Epoch 6/250] [Batch 32/34]  [G loss: 1.276385][Epoch 6/250] [Batch 33/34]  [G loss: 0.521794]Time taken for epoch 7 is 1.3190453052520752 sec
#
# [Epoch 6/250] [Batch 28/34]  [G loss: 0.465280][Epoch 6/250] [Batch 29/34]  [G loss: 0.361698][Epoch 6/250] [Batch 30/34]  [G loss: 0.308075][Epoch 6/250] [Batch 31/34]  [G loss: 0.631471][Epoch 6/250] [Batch 32/34]  [G loss: 1.276385][Epoch 6/250] [Batch 33/34]  [G loss: 0.521794]Time taken for epoch 7 is 1.3190453052520752 sec
#
# [Epoch 7/250] [Batch 0/34]  [G loss: 0.698011][Epoch 7/250] [Batch 1/34]  [G loss: 0.815437][Epoch 7/250] [Batch 2/34]  [G loss: 0.940916][Epoch 7/250] [Batch 3/34]  [G loss: 0.467040][Epoch 7/250] [Batch 4/34]  [G loss: 0.633212][Epoch 7/250] [Batch 5/34]  [G loss: 1.091148][Epoch 7/250] [Batch 0/34]  [G loss: 0.698011][Epoch 7/250] [Batch 1/34]  [G loss: 0.815437][Epoch 7/250] [Batch 2/34]  [G loss: 0.940916][Epoch 7/250] [Batch 3/34]  [G loss: 0.467040][Epoch 7/250] [Batch 4/34]  [G loss: 0.633212][Epoch 7/250] [Batch 5/34]  [G loss: 1.091148][Epoch 7/250] [Batch 6/34]  [G loss: 0.331922][Epoch 7/250] [Batch 7/34]  [G loss: 0.321442][Epoch 7/250] [Batch 8/34]  [G loss: 0.366593][Epoch 7/250] [Batch 9/34]  [G loss: 0.269429][Epoch 7/250] [Batch 10/34]  [G loss: 0.350309][Epoch 7/250] [Batch 11/34]  [G loss: 0.424346][Epoch 7/250] [Batch 6/34]  [G loss: 0.331922][Epoch 7/250] [Batch 7/34]  [G loss: 0.321442][Epoch 7/250] [Batch 8/34]  [G loss: 0.366593][Epoch 7/250] [Batch 9/34]  [G loss: 0.269429][Epoch 7/250] [Batch 10/34]  [G loss: 0.350309][Epoch 7/250] [Batch 11/34]  [G loss: 0.424346][Epoch 7/250] [Batch 12/34]  [G loss: 0.540637][Epoch 7/250] [Batch 13/34]  [G loss: 0.376574][Epoch 7/250] [Batch 14/34]  [G loss: 1.041552][Epoch 7/250] [Batch 15/34]  [G loss: 0.732093][Epoch 7/250] [Batch 16/34]  [G loss: 0.564799][Epoch 7/250] [Batch 17/34]  [G loss: 1.046885][Epoch 7/250] [Batch 12/34]  [G loss: 0.540637][Epoch 7/250] [Batch 13/34]  [G loss: 0.376574][Epoch 7/250] [Batch 14/34]  [G loss: 1.041552][Epoch 7/250] [Batch 15/34]  [G loss: 0.732093][Epoch 7/250] [Batch 16/34]  [G loss: 0.564799][Epoch 7/250] [Batch 17/34]  [G loss: 1.046885][Epoch 7/250] [Batch 18/34]  [G loss: 0.595242][Epoch 7/250] [Batch 19/34]  [G loss: 0.687283][Epoch 7/250] [Batch 20/34]  [G loss: 0.874019][Epoch 7/250] [Batch 21/34]  [G loss: 0.365232][Epoch 7/250] [Batch 22/34]  [G loss: 0.483031][Epoch 7/250] [Batch 23/34]  [G loss: 0.234414][Epoch 7/250] [Batch 18/34]  [G loss: 0.595242][Epoch 7/250] [Batch 19/34]  [G loss: 0.687283][Epoch 7/250] [Batch 20/34]  [G loss: 0.874019][Epoch 7/250] [Batch 21/34]  [G loss: 0.365232][Epoch 7/250] [Batch 22/34]  [G loss: 0.483031][Epoch 7/250] [Batch 23/34]  [G loss: 0.234414][Epoch 7/250] [Batch 24/34]  [G loss: 0.496457][Epoch 7/250] [Batch 25/34]  [G loss: 0.521054][Epoch 7/250] [Batch 26/34]  [G loss: 0.424110][Epoch 7/250] [Batch 27/34]  [G loss: 0.448374][Epoch 7/250] [Batch 28/34]  [G loss: 0.339414][Epoch 7/250] [Batch 29/34]  [G loss: 0.534799][Epoch 7/250] [Batch 24/34]  [G loss: 0.496457][Epoch 7/250] [Batch 25/34]  [G loss: 0.521054][Epoch 7/250] [Batch 26/34]  [G loss: 0.424110][Epoch 7/250] [Batch 27/34]  [G loss: 0.448374][Epoch 7/250] [Batch 28/34]  [G loss: 0.339414][Epoch 7/250] [Batch 29/34]  [G loss: 0.534799][Epoch 7/250] [Batch 30/34]  [G loss: 0.229772][Epoch 7/250] [Batch 31/34]  [G loss: 0.465830][Epoch 7/250] [Batch 32/34]  [G loss: 0.715473][Epoch 7/250] [Batch 33/34]  [G loss: 0.629248]Time taken for epoch 8 is 1.3178632259368896 sec
#
# [Epoch 8/250] [Batch 0/34]  [G loss: 0.347125][Epoch 8/250] [Batch 1/34]  [G loss: 0.449009][Epoch 7/250] [Batch 30/34]  [G loss: 0.229772][Epoch 7/250] [Batch 31/34]  [G loss: 0.465830][Epoch 7/250] [Batch 32/34]  [G loss: 0.715473][Epoch 7/250] [Batch 33/34]  [G loss: 0.629248]Time taken for epoch 8 is 1.3178632259368896 sec
#
# [Epoch 8/250] [Batch 0/34]  [G loss: 0.347125][Epoch 8/250] [Batch 1/34]  [G loss: 0.449009][Epoch 8/250] [Batch 2/34]  [G loss: 0.809507][Epoch 8/250] [Batch 3/34]  [G loss: 0.379415][Epoch 8/250] [Batch 4/34]  [G loss: 0.344765][Epoch 8/250] [Batch 5/34]  [G loss: 0.699678][Epoch 8/250] [Batch 6/34]  [G loss: 0.827712][Epoch 8/250] [Batch 7/34]  [G loss: 0.441211][Epoch 8/250] [Batch 2/34]  [G loss: 0.809507][Epoch 8/250] [Batch 3/34]  [G loss: 0.379415][Epoch 8/250] [Batch 4/34]  [G loss: 0.344765][Epoch 8/250] [Batch 5/34]  [G loss: 0.699678][Epoch 8/250] [Batch 6/34]  [G loss: 0.827712][Epoch 8/250] [Batch 7/34]  [G loss: 0.441211][Epoch 8/250] [Batch 8/34]  [G loss: 0.618914][Epoch 8/250] [Batch 9/34]  [G loss: 0.625466][Epoch 8/250] [Batch 10/34]  [G loss: 0.323544][Epoch 8/250] [Batch 11/34]  [G loss: 0.219418][Epoch 8/250] [Batch 12/34]  [G loss: 0.619586][Epoch 8/250] [Batch 13/34]  [G loss: 0.301328][Epoch 8/250] [Batch 8/34]  [G loss: 0.618914][Epoch 8/250] [Batch 9/34]  [G loss: 0.625466][Epoch 8/250] [Batch 10/34]  [G loss: 0.323544][Epoch 8/250] [Batch 11/34]  [G loss: 0.219418][Epoch 8/250] [Batch 12/34]  [G loss: 0.619586][Epoch 8/250] [Batch 13/34]  [G loss: 0.301328][Epoch 8/250] [Batch 14/34]  [G loss: 0.563585][Epoch 8/250] [Batch 15/34]  [G loss: 0.264514][Epoch 8/250] [Batch 16/34]  [G loss: 0.214272][Epoch 8/250] [Batch 17/34]  [G loss: 0.172152][Epoch 8/250] [Batch 18/34]  [G loss: 0.314531][Epoch 8/250] [Batch 19/34]  [G loss: 0.341877][Epoch 8/250] [Batch 14/34]  [G loss: 0.563585][Epoch 8/250] [Batch 15/34]  [G loss: 0.264514][Epoch 8/250] [Batch 16/34]  [G loss: 0.214272][Epoch 8/250] [Batch 17/34]  [G loss: 0.172152][Epoch 8/250] [Batch 18/34]  [G loss: 0.314531][Epoch 8/250] [Batch 19/34]  [G loss: 0.341877][Epoch 8/250] [Batch 20/34]  [G loss: 0.322571][Epoch 8/250] [Batch 21/34]  [G loss: 0.354880][Epoch 8/250] [Batch 22/34]  [G loss: 0.241308][Epoch 8/250] [Batch 23/34]  [G loss: 0.537772][Epoch 8/250] [Batch 24/34]  [G loss: 1.137910][Epoch 8/250] [Batch 20/34]  [G loss: 0.322571][Epoch 8/250] [Batch 21/34]  [G loss: 0.354880][Epoch 8/250] [Batch 22/34]  [G loss: 0.241308][Epoch 8/250] [Batch 23/34]  [G loss: 0.537772][Epoch 8/250] [Batch 24/34]  [G loss: 1.137910][Epoch 8/250] [Batch 25/34]  [G loss: 1.185162][Epoch 8/250] [Batch 26/34]  [G loss: 0.578360][Epoch 8/250] [Batch 27/34]  [G loss: 0.583893][Epoch 8/250] [Batch 28/34]  [G loss: 1.003523][Epoch 8/250] [Batch 29/34]  [G loss: 0.591808][Epoch 8/250] [Batch 25/34]  [G loss: 1.185162][Epoch 8/250] [Batch 26/34]  [G loss: 0.578360][Epoch 8/250] [Batch 27/34]  [G loss: 0.583893][Epoch 8/250] [Batch 28/34]  [G loss: 1.003523][Epoch 8/250] [Batch 29/34]  [G loss: 0.591808][Epoch 8/250] [Batch 30/34]  [G loss: 0.480751][Epoch 8/250] [Batch 31/34]  [G loss: 0.730829][Epoch 8/250] [Batch 32/34]  [G loss: 0.687166][Epoch 8/250] [Batch 33/34]  [G loss: 1.394331]Time taken for epoch 9 is 1.3363139629364014 sec
#
# [Epoch 9/250] [Batch 0/34]  [G loss: 0.510334][Epoch 9/250] [Batch 1/34]  [G loss: 0.978957][Epoch 8/250] [Batch 30/34]  [G loss: 0.480751][Epoch 8/250] [Batch 31/34]  [G loss: 0.730829][Epoch 8/250] [Batch 32/34]  [G loss: 0.687166][Epoch 8/250] [Batch 33/34]  [G loss: 1.394331]Time taken for epoch 9 is 1.3363139629364014 sec
#
# [Epoch 9/250] [Batch 0/34]  [G loss: 0.510334][Epoch 9/250] [Batch 1/34]  [G loss: 0.978957][Epoch 9/250] [Batch 2/34]  [G loss: 1.226943][Epoch 9/250] [Batch 3/34]  [G loss: 1.077356][Epoch 9/250] [Batch 4/34]  [G loss: 1.165008][Epoch 9/250] [Batch 5/34]  [G loss: 0.881238][Epoch 9/250] [Batch 6/34]  [G loss: 1.175937][Epoch 9/250] [Batch 2/34]  [G loss: 1.226943][Epoch 9/250] [Batch 3/34]  [G loss: 1.077356][Epoch 9/250] [Batch 4/34]  [G loss: 1.165008][Epoch 9/250] [Batch 5/34]  [G loss: 0.881238][Epoch 9/250] [Batch 6/34]  [G loss: 1.175937][Epoch 9/250] [Batch 7/34]  [G loss: 0.855082][Epoch 9/250] [Batch 8/34]  [G loss: 0.568185][Epoch 9/250] [Batch 9/34]  [G loss: 1.200230][Epoch 9/250] [Batch 10/34]  [G loss: 0.293480][Epoch 9/250] [Batch 11/34]  [G loss: 0.615392][Epoch 9/250] [Batch 12/34]  [G loss: 0.685879][Epoch 9/250] [Batch 7/34]  [G loss: 0.855082][Epoch 9/250] [Batch 8/34]  [G loss: 0.568185][Epoch 9/250] [Batch 9/34]  [G loss: 1.200230][Epoch 9/250] [Batch 10/34]  [G loss: 0.293480][Epoch 9/250] [Batch 11/34]  [G loss: 0.615392][Epoch 9/250] [Batch 12/34]  [G loss: 0.685879][Epoch 9/250] [Batch 13/34]  [G loss: 1.206477][Epoch 9/250] [Batch 14/34]  [G loss: 0.461399][Epoch 9/250] [Batch 15/34]  [G loss: 0.468266][Epoch 9/250] [Batch 16/34]  [G loss: 0.388089][Epoch 9/250] [Batch 17/34]  [G loss: 0.415528][Epoch 9/250] [Batch 13/34]  [G loss: 1.206477][Epoch 9/250] [Batch 14/34]  [G loss: 0.461399][Epoch 9/250] [Batch 15/34]  [G loss: 0.468266][Epoch 9/250] [Batch 16/34]  [G loss: 0.388089][Epoch 9/250] [Batch 17/34]  [G loss: 0.415528][Epoch 9/250] [Batch 18/34]  [G loss: 0.748776][Epoch 9/250] [Batch 19/34]  [G loss: 0.774093][Epoch 9/250] [Batch 20/34]  [G loss: 0.423271][Epoch 9/250] [Batch 21/34]  [G loss: 0.268615][Epoch 9/250] [Batch 22/34]  [G loss: 0.792459][Epoch 9/250] [Batch 23/34]  [G loss: 0.484270][Epoch 9/250] [Batch 18/34]  [G loss: 0.748776][Epoch 9/250] [Batch 19/34]  [G loss: 0.774093][Epoch 9/250] [Batch 20/34]  [G loss: 0.423271][Epoch 9/250] [Batch 21/34]  [G loss: 0.268615][Epoch 9/250] [Batch 22/34]  [G loss: 0.792459][Epoch 9/250] [Batch 23/34]  [G loss: 0.484270][Epoch 9/250] [Batch 24/34]  [G loss: 0.552998][Epoch 9/250] [Batch 25/34]  [G loss: 0.518574][Epoch 9/250] [Batch 26/34]  [G loss: 0.383849][Epoch 9/250] [Batch 27/34]  [G loss: 0.352638][Epoch 9/250] [Batch 28/34]  [G loss: 0.346283][Epoch 9/250] [Batch 29/34]  [G loss: 0.360954][Epoch 9/250] [Batch 24/34]  [G loss: 0.552998][Epoch 9/250] [Batch 25/34]  [G loss: 0.518574][Epoch 9/250] [Batch 26/34]  [G loss: 0.383849][Epoch 9/250] [Batch 27/34]  [G loss: 0.352638][Epoch 9/250] [Batch 28/34]  [G loss: 0.346283][Epoch 9/250] [Batch 29/34]  [G loss: 0.360954][Epoch 9/250] [Batch 30/34]  [G loss: 0.172839][Epoch 9/250] [Batch 31/34]  [G loss: 0.530831][Epoch 9/250] [Batch 32/34]  [G loss: 0.634171][Epoch 9/250] [Batch 33/34]  [G loss: 1.950675]Time taken for epoch 10 is 1.3321449756622314 sec
#
# [Epoch 10/250] [Batch 0/34]  [G loss: 0.533556][Epoch 10/250] [Batch 1/34]  [G loss: 0.327637][Epoch 9/250] [Batch 30/34]  [G loss: 0.172839][Epoch 9/250] [Batch 31/34]  [G loss: 0.530831][Epoch 9/250] [Batch 32/34]  [G loss: 0.634171][Epoch 9/250] [Batch 33/34]  [G loss: 1.950675]Time taken for epoch 10 is 1.3321449756622314 sec
#
# [Epoch 10/250] [Batch 0/34]  [G loss: 0.533556][Epoch 10/250] [Batch 1/34]  [G loss: 0.327637][Epoch 10/250] [Batch 2/34]  [G loss: 0.984227][Epoch 10/250] [Batch 3/34]  [G loss: 0.608392][Epoch 10/250] [Batch 4/34]  [G loss: 0.780886][Epoch 10/250] [Batch 5/34]  [G loss: 0.458314][Epoch 10/250] [Batch 6/34]  [G loss: 0.578395][Epoch 10/250] [Batch 7/34]  [G loss: 0.363551][Epoch 10/250] [Batch 2/34]  [G loss: 0.984227][Epoch 10/250] [Batch 3/34]  [G loss: 0.608392][Epoch 10/250] [Batch 4/34]  [G loss: 0.780886][Epoch 10/250] [Batch 5/34]  [G loss: 0.458314][Epoch 10/250] [Batch 6/34]  [G loss: 0.578395][Epoch 10/250] [Batch 7/34]  [G loss: 0.363551][Epoch 10/250] [Batch 8/34]  [G loss: 0.477277][Epoch 10/250] [Batch 9/34]  [G loss: 0.365345][Epoch 10/250] [Batch 10/34]  [G loss: 0.236585][Epoch 10/250] [Batch 11/34]  [G loss: 0.839814][Epoch 10/250] [Batch 12/34]  [G loss: 0.564627][Epoch 10/250] [Batch 8/34]  [G loss: 0.477277][Epoch 10/250] [Batch 9/34]  [G loss: 0.365345][Epoch 10/250] [Batch 10/34]  [G loss: 0.236585][Epoch 10/250] [Batch 11/34]  [G loss: 0.839814][Epoch 10/250] [Batch 12/34]  [G loss: 0.564627][Epoch 10/250] [Batch 13/34]  [G loss: 2.525987][Epoch 10/250] [Batch 14/34]  [G loss: 0.398497][Epoch 10/250] [Batch 15/34]  [G loss: 0.817078][Epoch 10/250] [Batch 16/34]  [G loss: 0.708567][Epoch 10/250] [Batch 17/34]  [G loss: 0.555617][Epoch 10/250] [Batch 13/34]  [G loss: 2.525987][Epoch 10/250] [Batch 14/34]  [G loss: 0.398497][Epoch 10/250] [Batch 15/34]  [G loss: 0.817078][Epoch 10/250] [Batch 16/34]  [G loss: 0.708567][Epoch 10/250] [Batch 17/34]  [G loss: 0.555617][Epoch 10/250] [Batch 18/34]  [G loss: 0.942103][Epoch 10/250] [Batch 19/34]  [G loss: 0.343736][Epoch 10/250] [Batch 20/34]  [G loss: 0.448560][Epoch 10/250] [Batch 21/34]  [G loss: 0.393725][Epoch 10/250] [Batch 22/34]  [G loss: 0.359052][Epoch 10/250] [Batch 23/34]  [G loss: 0.782646][Epoch 10/250] [Batch 18/34]  [G loss: 0.942103][Epoch 10/250] [Batch 19/34]  [G loss: 0.343736][Epoch 10/250] [Batch 20/34]  [G loss: 0.448560][Epoch 10/250] [Batch 21/34]  [G loss: 0.393725][Epoch 10/250] [Batch 22/34]  [G loss: 0.359052][Epoch 10/250] [Batch 23/34]  [G loss: 0.782646][Epoch 10/250] [Batch 24/34]  [G loss: 0.486384][Epoch 10/250] [Batch 25/34]  [G loss: 0.654960][Epoch 10/250] [Batch 26/34]  [G loss: 0.603311][Epoch 10/250] [Batch 27/34]  [G loss: 0.438974][Epoch 10/250] [Batch 28/34]  [G loss: 0.342143][Epoch 10/250] [Batch 29/34]  [G loss: 0.357297][Epoch 10/250] [Batch 24/34]  [G loss: 0.486384][Epoch 10/250] [Batch 25/34]  [G loss: 0.654960][Epoch 10/250] [Batch 26/34]  [G loss: 0.603311][Epoch 10/250] [Batch 27/34]  [G loss: 0.438974][Epoch 10/250] [Batch 28/34]  [G loss: 0.342143][Epoch 10/250] [Batch 29/34]  [G loss: 0.357297][Epoch 10/250] [Batch 30/34]  [G loss: 0.542603][Epoch 10/250] [Batch 31/34]  [G loss: 0.402311][Epoch 10/250] [Batch 32/34]  [G loss: 0.322074][Epoch 10/250] [Batch 33/34]  [G loss: 0.645363]Time taken for epoch 11 is 1.332141399383545 sec
#
# [Epoch 11/250] [Batch 0/34]  [G loss: 0.589058][Epoch 10/250] [Batch 30/34]  [G loss: 0.542603][Epoch 10/250] [Batch 31/34]  [G loss: 0.402311][Epoch 10/250] [Batch 32/34]  [G loss: 0.322074][Epoch 10/250] [Batch 33/34]  [G loss: 0.645363]Time taken for epoch 11 is 1.332141399383545 sec
#
# [Epoch 11/250] [Batch 0/34]  [G loss: 0.589058][Epoch 11/250] [Batch 1/34]  [G loss: 0.561391][Epoch 11/250] [Batch 2/34]  [G loss: 0.534433][Epoch 11/250] [Batch 3/34]  [G loss: 0.444470][Epoch 11/250] [Batch 4/34]  [G loss: 0.704768][Epoch 11/250] [Batch 5/34]  [G loss: 0.486652][Epoch 11/250] [Batch 6/34]  [G loss: 0.276706][Epoch 11/250] [Batch 1/34]  [G loss: 0.561391][Epoch 11/250] [Batch 2/34]  [G loss: 0.534433][Epoch 11/250] [Batch 3/34]  [G loss: 0.444470][Epoch 11/250] [Batch 4/34]  [G loss: 0.704768][Epoch 11/250] [Batch 5/34]  [G loss: 0.486652][Epoch 11/250] [Batch 6/34]  [G loss: 0.276706][Epoch 11/250] [Batch 7/34]  [G loss: 0.471870][Epoch 11/250] [Batch 8/34]  [G loss: 0.202171][Epoch 11/250] [Batch 9/34]  [G loss: 0.643506][Epoch 11/250] [Batch 10/34]  [G loss: 0.492399][Epoch 11/250] [Batch 11/34]  [G loss: 0.324976][Epoch 11/250] [Batch 12/34]  [G loss: 0.400106][Epoch 11/250] [Batch 7/34]  [G loss: 0.471870][Epoch 11/250] [Batch 8/34]  [G loss: 0.202171][Epoch 11/250] [Batch 9/34]  [G loss: 0.643506][Epoch 11/250] [Batch 10/34]  [G loss: 0.492399][Epoch 11/250] [Batch 11/34]  [G loss: 0.324976][Epoch 11/250] [Batch 12/34]  [G loss: 0.400106][Epoch 11/250] [Batch 13/34]  [G loss: 0.403746][Epoch 11/250] [Batch 14/34]  [G loss: 0.323180][Epoch 11/250] [Batch 15/34]  [G loss: 1.027591][Epoch 11/250] [Batch 16/34]  [G loss: 0.269209][Epoch 11/250] [Batch 17/34]  [G loss: 0.558471][Epoch 11/250] [Batch 13/34]  [G loss: 0.403746][Epoch 11/250] [Batch 14/34]  [G loss: 0.323180][Epoch 11/250] [Batch 15/34]  [G loss: 1.027591][Epoch 11/250] [Batch 16/34]  [G loss: 0.269209][Epoch 11/250] [Batch 17/34]  [G loss: 0.558471][Epoch 11/250] [Batch 18/34]  [G loss: 0.778202][Epoch 11/250] [Batch 19/34]  [G loss: 0.525185][Epoch 11/250] [Batch 20/34]  [G loss: 0.266043][Epoch 11/250] [Batch 21/34]  [G loss: 0.520894][Epoch 11/250] [Batch 22/34]  [G loss: 0.178015][Epoch 11/250] [Batch 23/34]  [G loss: 0.484165][Epoch 11/250] [Batch 18/34]  [G loss: 0.778202][Epoch 11/250] [Batch 19/34]  [G loss: 0.525185][Epoch 11/250] [Batch 20/34]  [G loss: 0.266043][Epoch 11/250] [Batch 21/34]  [G loss: 0.520894][Epoch 11/250] [Batch 22/34]  [G loss: 0.178015][Epoch 11/250] [Batch 23/34]  [G loss: 0.484165][Epoch 11/250] [Batch 24/34]  [G loss: 0.674508][Epoch 11/250] [Batch 25/34]  [G loss: 0.258956][Epoch 11/250] [Batch 26/34]  [G loss: 0.344829][Epoch 11/250] [Batch 27/34]  [G loss: 0.701526][Epoch 11/250] [Batch 28/34]  [G loss: 0.293264][Epoch 11/250] [Batch 24/34]  [G loss: 0.674508][Epoch 11/250] [Batch 25/34]  [G loss: 0.258956][Epoch 11/250] [Batch 26/34]  [G loss: 0.344829][Epoch 11/250] [Batch 27/34]  [G loss: 0.701526][Epoch 11/250] [Batch 28/34]  [G loss: 0.293264][Epoch 11/250] [Batch 29/34]  [G loss: 0.377612][Epoch 11/250] [Batch 30/34]  [G loss: 0.747667][Epoch 11/250] [Batch 31/34]  [G loss: 0.744121][Epoch 11/250] [Batch 32/34]  [G loss: 0.774425][Epoch 11/250] [Batch 33/34]  [G loss: 0.718413]Time taken for epoch 12 is 1.3569121360778809 sec
#
# [Epoch 12/250] [Batch 0/34]  [G loss: 1.073174][Epoch 11/250] [Batch 29/34]  [G loss: 0.377612][Epoch 11/250] [Batch 30/34]  [G loss: 0.747667][Epoch 11/250] [Batch 31/34]  [G loss: 0.744121][Epoch 11/250] [Batch 32/34]  [G loss: 0.774425][Epoch 11/250] [Batch 33/34]  [G loss: 0.718413]Time taken for epoch 12 is 1.3569121360778809 sec
#
# [Epoch 12/250] [Batch 0/34]  [G loss: 1.073174][Epoch 12/250] [Batch 1/34]  [G loss: 2.611155][Epoch 12/250] [Batch 2/34]  [G loss: 0.850563][Epoch 12/250] [Batch 3/34]  [G loss: 0.679597][Epoch 12/250] [Batch 4/34]  [G loss: 0.698167][Epoch 12/250] [Batch 5/34]  [G loss: 0.930338][Epoch 12/250] [Batch 6/34]  [G loss: 0.870161][Epoch 12/250] [Batch 1/34]  [G loss: 2.611155][Epoch 12/250] [Batch 2/34]  [G loss: 0.850563][Epoch 12/250] [Batch 3/34]  [G loss: 0.679597][Epoch 12/250] [Batch 4/34]  [G loss: 0.698167][Epoch 12/250] [Batch 5/34]  [G loss: 0.930338][Epoch 12/250] [Batch 6/34]  [G loss: 0.870161][Epoch 12/250] [Batch 7/34]  [G loss: 1.364858][Epoch 12/250] [Batch 8/34]  [G loss: 0.759640][Epoch 12/250] [Batch 9/34]  [G loss: 0.925520][Epoch 12/250] [Batch 10/34]  [G loss: 0.555460][Epoch 12/250] [Batch 11/34]  [G loss: 0.737840][Epoch 12/250] [Batch 12/34]  [G loss: 0.828755][Epoch 12/250] [Batch 7/34]  [G loss: 1.364858][Epoch 12/250] [Batch 8/34]  [G loss: 0.759640][Epoch 12/250] [Batch 9/34]  [G loss: 0.925520][Epoch 12/250] [Batch 10/34]  [G loss: 0.555460][Epoch 12/250] [Batch 11/34]  [G loss: 0.737840][Epoch 12/250] [Batch 12/34]  [G loss: 0.828755][Epoch 12/250] [Batch 13/34]  [G loss: 0.656242][Epoch 12/250] [Batch 14/34]  [G loss: 0.836254][Epoch 12/250] [Batch 15/34]  [G loss: 0.625817][Epoch 12/250] [Batch 16/34]  [G loss: 0.626104][Epoch 12/250] [Batch 17/34]  [G loss: 0.869798][Epoch 12/250] [Batch 18/34]  [G loss: 0.545099][Epoch 12/250] [Batch 13/34]  [G loss: 0.656242][Epoch 12/250] [Batch 14/34]  [G loss: 0.836254][Epoch 12/250] [Batch 15/34]  [G loss: 0.625817][Epoch 12/250] [Batch 16/34]  [G loss: 0.626104][Epoch 12/250] [Batch 17/34]  [G loss: 0.869798][Epoch 12/250] [Batch 18/34]  [G loss: 0.545099][Epoch 12/250] [Batch 19/34]  [G loss: 0.667813][Epoch 12/250] [Batch 20/34]  [G loss: 0.454520][Epoch 12/250] [Batch 21/34]  [G loss: 0.521116][Epoch 12/250] [Batch 22/34]  [G loss: 0.790256][Epoch 12/250] [Batch 23/34]  [G loss: 0.820318][Epoch 12/250] [Batch 24/34]  [G loss: 0.769028][Epoch 12/250] [Batch 19/34]  [G loss: 0.667813][Epoch 12/250] [Batch 20/34]  [G loss: 0.454520][Epoch 12/250] [Batch 21/34]  [G loss: 0.521116][Epoch 12/250] [Batch 22/34]  [G loss: 0.790256][Epoch 12/250] [Batch 23/34]  [G loss: 0.820318][Epoch 12/250] [Batch 24/34]  [G loss: 0.769028][Epoch 12/250] [Batch 25/34]  [G loss: 0.584275][Epoch 12/250] [Batch 26/34]  [G loss: 0.352347][Epoch 12/250] [Batch 27/34]  [G loss: 0.603308][Epoch 12/250] [Batch 28/34]  [G loss: 0.510037][Epoch 12/250] [Batch 29/34]  [G loss: 0.358661][Epoch 12/250] [Batch 30/34]  [G loss: 0.464039][Epoch 12/250] [Batch 25/34]  [G loss: 0.584275][Epoch 12/250] [Batch 26/34]  [G loss: 0.352347][Epoch 12/250] [Batch 27/34]  [G loss: 0.603308][Epoch 12/250] [Batch 28/34]  [G loss: 0.510037][Epoch 12/250] [Batch 29/34]  [G loss: 0.358661][Epoch 12/250] [Batch 30/34]  [G loss: 0.464039][Epoch 12/250] [Batch 31/34]  [G loss: 0.795858][Epoch 12/250] [Batch 32/34]  [G loss: 0.434413][Epoch 12/250] [Batch 33/34]  [G loss: 1.169301]Time taken for epoch 13 is 1.3232100009918213 sec
#
# [Epoch 13/250] [Batch 0/34]  [G loss: 0.441901][Epoch 13/250] [Batch 1/34]  [G loss: 0.517356][Epoch 13/250] [Batch 2/34]  [G loss: 0.563977][Epoch 12/250] [Batch 31/34]  [G loss: 0.795858][Epoch 12/250] [Batch 32/34]  [G loss: 0.434413][Epoch 12/250] [Batch 33/34]  [G loss: 1.169301]Time taken for epoch 13 is 1.3232100009918213 sec
#
# [Epoch 13/250] [Batch 0/34]  [G loss: 0.441901][Epoch 13/250] [Batch 1/34]  [G loss: 0.517356][Epoch 13/250] [Batch 2/34]  [G loss: 0.563977][Epoch 13/250] [Batch 3/34]  [G loss: 0.353440][Epoch 13/250] [Batch 4/34]  [G loss: 0.489371][Epoch 13/250] [Batch 5/34]  [G loss: 0.886144][Epoch 13/250] [Batch 6/34]  [G loss: 0.789558][Epoch 13/250] [Batch 7/34]  [G loss: 0.470653][Epoch 13/250] [Batch 8/34]  [G loss: 0.646802][Epoch 13/250] [Batch 3/34]  [G loss: 0.353440][Epoch 13/250] [Batch 4/34]  [G loss: 0.489371][Epoch 13/250] [Batch 5/34]  [G loss: 0.886144][Epoch 13/250] [Batch 6/34]  [G loss: 0.789558][Epoch 13/250] [Batch 7/34]  [G loss: 0.470653][Epoch 13/250] [Batch 8/34]  [G loss: 0.646802][Epoch 13/250] [Batch 9/34]  [G loss: 0.368306][Epoch 13/250] [Batch 10/34]  [G loss: 1.047254][Epoch 13/250] [Batch 11/34]  [G loss: 0.317709][Epoch 13/250] [Batch 12/34]  [G loss: 0.581085][Epoch 13/250] [Batch 13/34]  [G loss: 0.328950][Epoch 13/250] [Batch 14/34]  [G loss: 0.366185][Epoch 13/250] [Batch 9/34]  [G loss: 0.368306][Epoch 13/250] [Batch 10/34]  [G loss: 1.047254][Epoch 13/250] [Batch 11/34]  [G loss: 0.317709][Epoch 13/250] [Batch 12/34]  [G loss: 0.581085][Epoch 13/250] [Batch 13/34]  [G loss: 0.328950][Epoch 13/250] [Batch 14/34]  [G loss: 0.366185][Epoch 13/250] [Batch 15/34]  [G loss: 0.427611][Epoch 13/250] [Batch 16/34]  [G loss: 0.387713][Epoch 13/250] [Batch 17/34]  [G loss: 0.500379][Epoch 13/250] [Batch 18/34]  [G loss: 0.562414][Epoch 13/250] [Batch 19/34]  [G loss: 0.708880][Epoch 13/250] [Batch 20/34]  [G loss: 0.428834][Epoch 13/250] [Batch 15/34]  [G loss: 0.427611][Epoch 13/250] [Batch 16/34]  [G loss: 0.387713][Epoch 13/250] [Batch 17/34]  [G loss: 0.500379][Epoch 13/250] [Batch 18/34]  [G loss: 0.562414][Epoch 13/250] [Batch 19/34]  [G loss: 0.708880][Epoch 13/250] [Batch 20/34]  [G loss: 0.428834][Epoch 13/250] [Batch 21/34]  [G loss: 0.387810][Epoch 13/250] [Batch 22/34]  [G loss: 0.447434][Epoch 13/250] [Batch 23/34]  [G loss: 0.658643][Epoch 13/250] [Batch 24/34]  [G loss: 0.395038][Epoch 13/250] [Batch 25/34]  [G loss: 0.340590][Epoch 13/250] [Batch 26/34]  [G loss: 0.541922][Epoch 13/250] [Batch 21/34]  [G loss: 0.387810][Epoch 13/250] [Batch 22/34]  [G loss: 0.447434][Epoch 13/250] [Batch 23/34]  [G loss: 0.658643][Epoch 13/250] [Batch 24/34]  [G loss: 0.395038][Epoch 13/250] [Batch 25/34]  [G loss: 0.340590][Epoch 13/250] [Batch 26/34]  [G loss: 0.541922][Epoch 13/250] [Batch 27/34]  [G loss: 0.251435][Epoch 13/250] [Batch 28/34]  [G loss: 0.364974][Epoch 13/250] [Batch 29/34]  [G loss: 0.378115][Epoch 13/250] [Batch 30/34]  [G loss: 0.273003][Epoch 13/250] [Batch 31/34]  [G loss: 0.295528][Epoch 13/250] [Batch 32/34]  [G loss: 0.806179][Epoch 13/250] [Batch 27/34]  [G loss: 0.251435][Epoch 13/250] [Batch 28/34]  [G loss: 0.364974][Epoch 13/250] [Batch 29/34]  [G loss: 0.378115][Epoch 13/250] [Batch 30/34]  [G loss: 0.273003][Epoch 13/250] [Batch 31/34]  [G loss: 0.295528][Epoch 13/250] [Batch 32/34]  [G loss: 0.806179][Epoch 13/250] [Batch 33/34]  [G loss: 0.679772]Time taken for epoch 14 is 1.3206870555877686 sec
#
# [Epoch 14/250] [Batch 0/34]  [G loss: 0.588272][Epoch 14/250] [Batch 1/34]  [G loss: 0.828431][Epoch 14/250] [Batch 2/34]  [G loss: 0.608604][Epoch 14/250] [Batch 3/34]  [G loss: 0.512293][Epoch 14/250] [Batch 4/34]  [G loss: 0.645347][Epoch 13/250] [Batch 33/34]  [G loss: 0.679772]Time taken for epoch 14 is 1.3206870555877686 sec
#
# ...
#
# [Epoch 246/250] [Batch 0/34]  [G loss: 0.166523][Epoch 246/250] [Batch 1/34]  [G loss: 0.084990][Epoch 246/250] [Batch 2/34]  [G loss: 0.189641][Epoch 246/250] [Batch 3/34]  [G loss: 0.145437][Epoch 245/250] [Batch 32/34]  [G loss: 0.135961][Epoch 245/250] [Batch 33/34]  [G loss: 0.203950]Time taken for epoch 246 is 1.2943081855773926 sec
#
# [Epoch 246/250] [Batch 0/34]  [G loss: 0.166523][Epoch 246/250] [Batch 1/34]  [G loss: 0.084990][Epoch 246/250] [Batch 2/34]  [G loss: 0.189641][Epoch 246/250] [Batch 3/34]  [G loss: 0.145437][Epoch 246/250] [Batch 4/34]  [G loss: 0.093386][Epoch 246/250] [Batch 5/34]  [G loss: 0.130479][Epoch 246/250] [Batch 6/34]  [G loss: 0.289931][Epoch 246/250] [Batch 7/34]  [G loss: 0.241298][Epoch 246/250] [Batch 8/34]  [G loss: 0.146585][Epoch 246/250] [Batch 9/34]  [G loss: 0.112384][Epoch 246/250] [Batch 4/34]  [G loss: 0.093386][Epoch 246/250] [Batch 5/34]  [G loss: 0.130479][Epoch 246/250] [Batch 6/34]  [G loss: 0.289931][Epoch 246/250] [Batch 7/34]  [G loss: 0.241298][Epoch 246/250] [Batch 8/34]  [G loss: 0.146585][Epoch 246/250] [Batch 9/34]  [G loss: 0.112384][Epoch 246/250] [Batch 10/34]  [G loss: 0.294280][Epoch 246/250] [Batch 11/34]  [G loss: 0.204290][Epoch 246/250] [Batch 12/34]  [G loss: 0.409147][Epoch 246/250] [Batch 13/34]  [G loss: 1.506934][Epoch 246/250] [Batch 14/34]  [G loss: 1.374671][Epoch 246/250] [Batch 15/34]  [G loss: 1.023231][Epoch 246/250] [Batch 10/34]  [G loss: 0.294280][Epoch 246/250] [Batch 11/34]  [G loss: 0.204290][Epoch 246/250] [Batch 12/34]  [G loss: 0.409147][Epoch 246/250] [Batch 13/34]  [G loss: 1.506934][Epoch 246/250] [Batch 14/34]  [G loss: 1.374671][Epoch 246/250] [Batch 15/34]  [G loss: 1.023231][Epoch 246/250] [Batch 16/34]  [G loss: 1.623066][Epoch 246/250] [Batch 17/34]  [G loss: 1.482700][Epoch 246/250] [Batch 18/34]  [G loss: 0.469791][Epoch 246/250] [Batch 19/34]  [G loss: 0.761544][Epoch 246/250] [Batch 20/34]  [G loss: 0.462578][Epoch 246/250] [Batch 21/34]  [G loss: 0.391209][Epoch 246/250] [Batch 16/34]  [G loss: 1.623066][Epoch 246/250] [Batch 17/34]  [G loss: 1.482700][Epoch 246/250] [Batch 18/34]  [G loss: 0.469791][Epoch 246/250] [Batch 19/34]  [G loss: 0.761544][Epoch 246/250] [Batch 20/34]  [G loss: 0.462578][Epoch 246/250] [Batch 21/34]  [G loss: 0.391209][Epoch 246/250] [Batch 22/34]  [G loss: 0.400262][Epoch 246/250] [Batch 23/34]  [G loss: 0.286654][Epoch 246/250] [Batch 24/34]  [G loss: 0.195346][Epoch 246/250] [Batch 25/34]  [G loss: 0.293741][Epoch 246/250] [Batch 26/34]  [G loss: 0.257734][Epoch 246/250] [Batch 27/34]  [G loss: 0.589735][Epoch 246/250] [Batch 22/34]  [G loss: 0.400262][Epoch 246/250] [Batch 23/34]  [G loss: 0.286654][Epoch 246/250] [Batch 24/34]  [G loss: 0.195346][Epoch 246/250] [Batch 25/34]  [G loss: 0.293741][Epoch 246/250] [Batch 26/34]  [G loss: 0.257734][Epoch 246/250] [Batch 27/34]  [G loss: 0.589735][Epoch 246/250] [Batch 28/34]  [G loss: 0.344101][Epoch 246/250] [Batch 29/34]  [G loss: 0.412444][Epoch 246/250] [Batch 30/34]  [G loss: 0.662326][Epoch 246/250] [Batch 31/34]  [G loss: 0.210666][Epoch 246/250] [Batch 32/34]  [G loss: 0.358630][Epoch 246/250] [Batch 33/34]  [G loss: 0.455098]Time taken for epoch 247 is 1.2939417362213135 sec
#
# [Epoch 246/250] [Batch 28/34]  [G loss: 0.344101][Epoch 246/250] [Batch 29/34]  [G loss: 0.412444][Epoch 246/250] [Batch 30/34]  [G loss: 0.662326][Epoch 246/250] [Batch 31/34]  [G loss: 0.210666][Epoch 246/250] [Batch 32/34]  [G loss: 0.358630][Epoch 246/250] [Batch 33/34]  [G loss: 0.455098]Time taken for epoch 247 is 1.2939417362213135 sec
#
# [Epoch 247/250] [Batch 0/34]  [G loss: 0.294521][Epoch 247/250] [Batch 1/34]  [G loss: 0.316230][Epoch 247/250] [Batch 2/34]  [G loss: 0.444541][Epoch 247/250] [Batch 3/34]  [G loss: 0.221614][Epoch 247/250] [Batch 4/34]  [G loss: 0.213097][Epoch 247/250] [Batch 0/34]  [G loss: 0.294521][Epoch 247/250] [Batch 1/34]  [G loss: 0.316230][Epoch 247/250] [Batch 2/34]  [G loss: 0.444541][Epoch 247/250] [Batch 3/34]  [G loss: 0.221614][Epoch 247/250] [Batch 4/34]  [G loss: 0.213097][Epoch 247/250] [Batch 5/34]  [G loss: 0.219159][Epoch 247/250] [Batch 6/34]  [G loss: 0.558298][Epoch 247/250] [Batch 7/34]  [G loss: 0.186999][Epoch 247/250] [Batch 8/34]  [G loss: 0.247222][Epoch 247/250] [Batch 9/34]  [G loss: 0.192335][Epoch 247/250] [Batch 10/34]  [G loss: 0.181246][Epoch 247/250] [Batch 5/34]  [G loss: 0.219159][Epoch 247/250] [Batch 6/34]  [G loss: 0.558298][Epoch 247/250] [Batch 7/34]  [G loss: 0.186999][Epoch 247/250] [Batch 8/34]  [G loss: 0.247222][Epoch 247/250] [Batch 9/34]  [G loss: 0.192335][Epoch 247/250] [Batch 10/34]  [G loss: 0.181246][Epoch 247/250] [Batch 11/34]  [G loss: 0.276509][Epoch 247/250] [Batch 12/34]  [G loss: 0.306721][Epoch 247/250] [Batch 13/34]  [G loss: 0.152530][Epoch 247/250] [Batch 14/34]  [G loss: 0.158568][Epoch 247/250] [Batch 15/34]  [G loss: 0.159860][Epoch 247/250] [Batch 16/34]  [G loss: 0.126508][Epoch 247/250] [Batch 11/34]  [G loss: 0.276509][Epoch 247/250] [Batch 12/34]  [G loss: 0.306721][Epoch 247/250] [Batch 13/34]  [G loss: 0.152530][Epoch 247/250] [Batch 14/34]  [G loss: 0.158568][Epoch 247/250] [Batch 15/34]  [G loss: 0.159860][Epoch 247/250] [Batch 16/34]  [G loss: 0.126508][Epoch 247/250] [Batch 17/34]  [G loss: 0.168799][Epoch 247/250] [Batch 18/34]  [G loss: 0.168936][Epoch 247/250] [Batch 19/34]  [G loss: 0.126693][Epoch 247/250] [Batch 20/34]  [G loss: 0.372672][Epoch 247/250] [Batch 21/34]  [G loss: 0.569214][Epoch 247/250] [Batch 22/34]  [G loss: 0.346307][Epoch 247/250] [Batch 17/34]  [G loss: 0.168799][Epoch 247/250] [Batch 18/34]  [G loss: 0.168936][Epoch 247/250] [Batch 19/34]  [G loss: 0.126693][Epoch 247/250] [Batch 20/34]  [G loss: 0.372672][Epoch 247/250] [Batch 21/34]  [G loss: 0.569214][Epoch 247/250] [Batch 22/34]  [G loss: 0.346307][Epoch 247/250] [Batch 23/34]  [G loss: 0.385662][Epoch 247/250] [Batch 24/34]  [G loss: 0.132917][Epoch 247/250] [Batch 25/34]  [G loss: 0.281546][Epoch 247/250] [Batch 26/34]  [G loss: 0.144131][Epoch 247/250] [Batch 27/34]  [G loss: 0.111031][Epoch 247/250] [Batch 28/34]  [G loss: 0.202964][Epoch 247/250] [Batch 23/34]  [G loss: 0.385662][Epoch 247/250] [Batch 24/34]  [G loss: 0.132917][Epoch 247/250] [Batch 25/34]  [G loss: 0.281546][Epoch 247/250] [Batch 26/34]  [G loss: 0.144131][Epoch 247/250] [Batch 27/34]  [G loss: 0.111031][Epoch 247/250] [Batch 28/34]  [G loss: 0.202964][Epoch 247/250] [Batch 29/34]  [G loss: 0.257679][Epoch 247/250] [Batch 30/34]  [G loss: 0.353411][Epoch 247/250] [Batch 31/34]  [G loss: 0.140465][Epoch 247/250] [Batch 32/34]  [G loss: 0.314559][Epoch 247/250] [Batch 33/34]  [G loss: 0.344057]Time taken for epoch 248 is 1.3044252395629883 sec
#
# [Epoch 248/250] [Batch 0/34]  [G loss: 0.305008][Epoch 247/250] [Batch 29/34]  [G loss: 0.257679][Epoch 247/250] [Batch 30/34]  [G loss: 0.353411][Epoch 247/250] [Batch 31/34]  [G loss: 0.140465][Epoch 247/250] [Batch 32/34]  [G loss: 0.314559][Epoch 247/250] [Batch 33/34]  [G loss: 0.344057]Time taken for epoch 248 is 1.3044252395629883 sec
#
# [Epoch 248/250] [Batch 0/34]  [G loss: 0.305008][Epoch 248/250] [Batch 1/34]  [G loss: 0.411684][Epoch 248/250] [Batch 2/34]  [G loss: 0.207394][Epoch 248/250] [Batch 3/34]  [G loss: 0.140068][Epoch 248/250] [Batch 4/34]  [G loss: 0.218607][Epoch 248/250] [Batch 5/34]  [G loss: 0.147649][Epoch 248/250] [Batch 6/34]  [G loss: 0.230981][Epoch 248/250] [Batch 1/34]  [G loss: 0.411684][Epoch 248/250] [Batch 2/34]  [G loss: 0.207394][Epoch 248/250] [Batch 3/34]  [G loss: 0.140068][Epoch 248/250] [Batch 4/34]  [G loss: 0.218607][Epoch 248/250] [Batch 5/34]  [G loss: 0.147649][Epoch 248/250] [Batch 6/34]  [G loss: 0.230981][Epoch 248/250] [Batch 7/34]  [G loss: 0.332434][Epoch 248/250] [Batch 8/34]  [G loss: 0.284209][Epoch 248/250] [Batch 9/34]  [G loss: 0.133956][Epoch 248/250] [Batch 10/34]  [G loss: 0.177761][Epoch 248/250] [Batch 11/34]  [G loss: 0.138725][Epoch 248/250] [Batch 12/34]  [G loss: 0.170346][Epoch 248/250] [Batch 7/34]  [G loss: 0.332434][Epoch 248/250] [Batch 8/34]  [G loss: 0.284209][Epoch 248/250] [Batch 9/34]  [G loss: 0.133956][Epoch 248/250] [Batch 10/34]  [G loss: 0.177761][Epoch 248/250] [Batch 11/34]  [G loss: 0.138725][Epoch 248/250] [Batch 12/34]  [G loss: 0.170346][Epoch 248/250] [Batch 13/34]  [G loss: 0.312255][Epoch 248/250] [Batch 14/34]  [G loss: 0.244880][Epoch 248/250] [Batch 15/34]  [G loss: 0.211476][Epoch 248/250] [Batch 16/34]  [G loss: 0.389299][Epoch 248/250] [Batch 17/34]  [G loss: 0.090440][Epoch 248/250] [Batch 18/34]  [G loss: 0.395083][Epoch 248/250] [Batch 13/34]  [G loss: 0.312255][Epoch 248/250] [Batch 14/34]  [G loss: 0.244880][Epoch 248/250] [Batch 15/34]  [G loss: 0.211476][Epoch 248/250] [Batch 16/34]  [G loss: 0.389299][Epoch 248/250] [Batch 17/34]  [G loss: 0.090440][Epoch 248/250] [Batch 18/34]  [G loss: 0.395083][Epoch 248/250] [Batch 19/34]  [G loss: 0.152480][Epoch 248/250] [Batch 20/34]  [G loss: 0.239573][Epoch 248/250] [Batch 21/34]  [G loss: 0.145015][Epoch 248/250] [Batch 22/34]  [G loss: 0.425594][Epoch 248/250] [Batch 23/34]  [G loss: 0.250031][Epoch 248/250] [Batch 24/34]  [G loss: 0.117515][Epoch 248/250] [Batch 19/34]  [G loss: 0.152480][Epoch 248/250] [Batch 20/34]  [G loss: 0.239573][Epoch 248/250] [Batch 21/34]  [G loss: 0.145015][Epoch 248/250] [Batch 22/34]  [G loss: 0.425594][Epoch 248/250] [Batch 23/34]  [G loss: 0.250031][Epoch 248/250] [Batch 24/34]  [G loss: 0.117515][Epoch 248/250] [Batch 25/34]  [G loss: 0.091298][Epoch 248/250] [Batch 26/34]  [G loss: 0.121789][Epoch 248/250] [Batch 27/34]  [G loss: 0.308125][Epoch 248/250] [Batch 28/34]  [G loss: 0.411667][Epoch 248/250] [Batch 29/34]  [G loss: 0.160217][Epoch 248/250] [Batch 30/34]  [G loss: 0.141548][Epoch 248/250] [Batch 25/34]  [G loss: 0.091298][Epoch 248/250] [Batch 26/34]  [G loss: 0.121789][Epoch 248/250] [Batch 27/34]  [G loss: 0.308125][Epoch 248/250] [Batch 28/34]  [G loss: 0.411667][Epoch 248/250] [Batch 29/34]  [G loss: 0.160217][Epoch 248/250] [Batch 30/34]  [G loss: 0.141548][Epoch 248/250] [Batch 31/34]  [G loss: 0.190129][Epoch 248/250] [Batch 32/34]  [G loss: 0.144728][Epoch 248/250] [Batch 33/34]  [G loss: 0.300254]Time taken for epoch 249 is 1.2946276664733887 sec
#
# [Epoch 249/250] [Batch 0/34]  [G loss: 0.288581][Epoch 249/250] [Batch 1/34]  [G loss: 0.258882][Epoch 249/250] [Batch 2/34]  [G loss: 0.353330][Epoch 248/250] [Batch 31/34]  [G loss: 0.190129][Epoch 248/250] [Batch 32/34]  [G loss: 0.144728][Epoch 248/250] [Batch 33/34]  [G loss: 0.300254]Time taken for epoch 249 is 1.2946276664733887 sec
#
# [Epoch 249/250] [Batch 0/34]  [G loss: 0.288581][Epoch 249/250] [Batch 1/34]  [G loss: 0.258882][Epoch 249/250] [Batch 2/34]  [G loss: 0.353330][Epoch 249/250] [Batch 3/34]  [G loss: 0.530788][Epoch 249/250] [Batch 4/34]  [G loss: 0.186964][Epoch 249/250] [Batch 5/34]  [G loss: 0.233735][Epoch 249/250] [Batch 6/34]  [G loss: 0.110323][Epoch 249/250] [Batch 7/34]  [G loss: 0.121315][Epoch 249/250] [Batch 8/34]  [G loss: 0.315635][Epoch 249/250] [Batch 3/34]  [G loss: 0.530788][Epoch 249/250] [Batch 4/34]  [G loss: 0.186964][Epoch 249/250] [Batch 5/34]  [G loss: 0.233735][Epoch 249/250] [Batch 6/34]  [G loss: 0.110323][Epoch 249/250] [Batch 7/34]  [G loss: 0.121315][Epoch 249/250] [Batch 8/34]  [G loss: 0.315635][Epoch 249/250] [Batch 9/34]  [G loss: 0.101982][Epoch 249/250] [Batch 10/34]  [G loss: 0.182052][Epoch 249/250] [Batch 11/34]  [G loss: 0.167453][Epoch 249/250] [Batch 12/34]  [G loss: 0.070076][Epoch 249/250] [Batch 13/34]  [G loss: 0.090250][Epoch 249/250] [Batch 14/34]  [G loss: 0.082400][Epoch 249/250] [Batch 9/34]  [G loss: 0.101982][Epoch 249/250] [Batch 10/34]  [G loss: 0.182052][Epoch 249/250] [Batch 11/34]  [G loss: 0.167453][Epoch 249/250] [Batch 12/34]  [G loss: 0.070076][Epoch 249/250] [Batch 13/34]  [G loss: 0.090250][Epoch 249/250] [Batch 14/34]  [G loss: 0.082400][Epoch 249/250] [Batch 15/34]  [G loss: 0.174648][Epoch 249/250] [Batch 16/34]  [G loss: 0.364925][Epoch 249/250] [Batch 17/34]  [G loss: 0.182837][Epoch 249/250] [Batch 18/34]  [G loss: 0.151025][Epoch 249/250] [Batch 19/34]  [G loss: 0.225499][Epoch 249/250] [Batch 20/34]  [G loss: 0.093184][Epoch 249/250] [Batch 15/34]  [G loss: 0.174648][Epoch 249/250] [Batch 16/34]  [G loss: 0.364925][Epoch 249/250] [Batch 17/34]  [G loss: 0.182837][Epoch 249/250] [Batch 18/34]  [G loss: 0.151025][Epoch 249/250] [Batch 19/34]  [G loss: 0.225499][Epoch 249/250] [Batch 20/34]  [G loss: 0.093184][Epoch 249/250] [Batch 21/34]  [G loss: 0.187026][Epoch 249/250] [Batch 22/34]  [G loss: 0.138537][Epoch 249/250] [Batch 23/34]  [G loss: 0.227780][Epoch 249/250] [Batch 24/34]  [G loss: 0.234623][Epoch 249/250] [Batch 25/34]  [G loss: 0.091983][Epoch 249/250] [Batch 26/34]  [G loss: 0.195165][Epoch 249/250] [Batch 21/34]  [G loss: 0.187026][Epoch 249/250] [Batch 22/34]  [G loss: 0.138537][Epoch 249/250] [Batch 23/34]  [G loss: 0.227780][Epoch 249/250] [Batch 24/34]  [G loss: 0.234623][Epoch 249/250] [Batch 25/34]  [G loss: 0.091983][Epoch 249/250] [Batch 26/34]  [G loss: 0.195165][Epoch 249/250] [Batch 27/34]  [G loss: 0.202958][Epoch 249/250] [Batch 28/34]  [G loss: 0.076320][Epoch 249/250] [Batch 29/34]  [G loss: 0.097527][Epoch 249/250] [Batch 30/34]  [G loss: 0.143216][Epoch 249/250] [Batch 31/34]  [G loss: 0.075032][Epoch 249/250] [Batch 32/34]  [G loss: 0.183336][Epoch 249/250] [Batch 33/34]  [G loss: 7.703876]Time taken for epoch 250 is 1.301192283630371 sec
#
# [Epoch 249/250] [Batch 27/34]  [G loss: 0.202958][Epoch 249/250] [Batch 28/34]  [G loss: 0.076320][Epoch 249/250] [Batch 29/34]  [G loss: 0.097527][Epoch 249/250] [Batch 30/34]  [G loss: 0.143216][Epoch 249/250] [Batch 31/34]  [G loss: 0.075032][Epoch 249/250] [Batch 32/34]  [G loss: 0.183336][Epoch 249/250] [Batch 33/34]  [G loss: 7.703876]Time taken for epoch 250 is 1.301192283630371 sec

# %%
loss_list = [tensor.item() for tensor in loss]

# %%
import matplotlib.pyplot as plt


# Plot the loss curve

x = range(0, 250)  #epochを９９から０にしたのでこちらも９９から０にしました

plt.plot(x, loss_list, label="Training Loss")

plt.xlabel("Epoch")

plt.ylabel("Loss")

plt.title("Training Loss Curve")

plt.legend()

plt.show()

# %%
# !ls /content/drive/MyDrive/GISR_code/models/generator_*
# Out:
# 3892.73s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ls: '/content/drive/MyDrive/GISR_code/models/generator_*' にアクセスできません: そのようなファイルやディレクトリはありません

# %% [markdown]
# # Model testing

# %%
import argparse
from skimage import io
import os
import numpy as np
import math
import itertools
import tifffile as tiff
import sys
import torchvision.transforms as transforms
from torchvision.utils import save_image, make_grid
from torch.utils.data import DataLoader
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
from torchvision.models import vgg19
import glob
import random
import torch
from torch.utils.data import Dataset
from PIL import Image
import time
import datetime
from torch.utils.tensorboard import SummaryWriter

# %%
class FeatureExtractor(nn.Module):
    def __init__(self):
        super(FeatureExtractor, self).__init__()
        vgg19_model = vgg19(pretrained=True)
        self.feature_extractor = nn.Sequential(
            *list(vgg19_model.features.children())[:18]
        )

    def forward(self, img):
        return self.feature_extractor(img)


class ResidualBlock(nn.Module):
    def __init__(self, in_features):
        super(ResidualBlock, self).__init__()
        self.conv_block = nn.Sequential(
            nn.Conv2d(in_features, in_features, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_features, 0.8),
            nn.PReLU(),
            nn.Conv2d(in_features, in_features, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(in_features, 0.8),
        )

    def forward(self, x):
        return x + self.conv_block(x)


class GeneratorResNet(nn.Module):
    def __init__(self, in_channels=1, out_channels=1, n_residual_blocks=16):
        super(GeneratorResNet, self).__init__()

        # First layer
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels, 64, kernel_size=9, stride=1, padding=4), nn.PReLU()
        )

        # Residual blocks
        res_blocks = []
        for _ in range(n_residual_blocks):
            res_blocks.append(ResidualBlock(64))
        self.res_blocks = nn.Sequential(*res_blocks)

        # Second conv layer post residual blocks
        self.conv2 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64, 0.8),
        )

        # Upsampling layers
        upsampling = []
        for out_features in range(1):
            upsampling += [
                # nn.Upsample(scale_factor=2),
                nn.Conv2d(64, 256, 3, 1, 1),
                nn.BatchNorm2d(256),
                # nn.Upsample(scale_factor=2, mode='bicubic'),
                nn.PixelShuffle(upscale_factor=2),
                nn.PReLU(),
            ]
        self.upsampling = nn.Sequential(*upsampling)

        # Final output layer
        self.conv3 = nn.Sequential(
            nn.Conv2d(64, out_channels, kernel_size=9, stride=2, padding=4), nn.Tanh()
        )

    def forward(self, x):
        out1 = self.conv1(x)
        out = self.res_blocks(out1)
        out2 = self.conv2(out)
        out = torch.add(out1, out2)
        out = self.upsampling(out)
        out = self.conv3(out)
        return out


class D(nn.Module):
    def __init__(self, input_shape):
        super(D, self).__init__()

        self.input_shape = input_shape
        in_channels, in_height, in_width = self.input_shape
        patch_h, patch_w = int(in_height / 2**4), int(in_width / 2**4)
        self.output_shape = (1, patch_h, patch_w)

        def d_block(in_filters, out_filters, first_block=False):
            layers = []
            layers.append(
                nn.Conv2d(in_filters, out_filters, kernel_size=3, stride=1, padding=1)
            )
            if not first_block:
                layers.append(nn.BatchNorm2d(out_filters))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            layers.append(
                nn.Conv2d(out_filters, out_filters, kernel_size=3, stride=2, padding=1)
            )
            layers.append(nn.BatchNorm2d(out_filters))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        layers = []
        in_filters = in_channels
        for i, out_filters in enumerate([64, 128, 256, 512]):
            layers.extend(d_block(in_filters, out_filters, first_block=(i == 0)))
            in_filters = out_filters

        layers.append(nn.Conv2d(out_filters, 1, kernel_size=3, stride=1, padding=1))

        self.model = nn.Sequential(*layers)

    def forward(self, img):
        return self.model(img)


class RMSELoss(nn.Module):
    def __init__(self):
        super(RMSELoss, self).__init__()

    def forward(self, pred, truth):
        return torch.sqrt(torch.mean((pred - truth) ** 2))
        torch.square((pred - truth) ** 2)

# %% [markdown]
# ## Load the model

# %%
path = "/home/s1300211/Documents/DEM-Super-Resolution"  # Your folder path
sample = "R1"  # Your file name of tiff
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])
lr = 0.0002
b1 = 0.5
b2 = 0.999
hr_height = 64
hr_width = 64
h = 1414.8213    # もとは2335
l = 482.3734     # もとは304
cuda = torch.cuda.is_available()
hr_shape = (hr_height, hr_width)
generator = GeneratorResNet()
feature_extractor = FeatureExtractor()
feature_extractor.eval()
criterion_GAN = RMSELoss()
criterion_content = torch.nn.L1Loss()
if cuda:
    generator = generator.cuda()
    feature_extractor = feature_extractor.cuda()
    criterion_GAN = criterion_GAN.cuda()
    criterion_content = criterion_content.cuda()
generator.load_state_dict(
    torch.load("/home/s1300211/Documents/DEM-Super-Resolution/models/generator_240.pth")
)
optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr, betas=(b1, b2))
Tensor = torch.cuda.FloatTensor if cuda else torch.Tensor
# Out:
# /home/s1300211/Documents/venv_2/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/s1300211/Documents/venv_2/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ## Generate test data

# %%
import rasterio
from rasterio.plot import show

fp = r"/home/s1300211/Documents/datasets/test/center_tile.tif"
img = rasterio.open(fp)
show(img)
# Out:
# <Axes: >

# %%
img.width
# Out:
# 500

# %%
img.height
# Out:
# 500

# %%
img_lr = img.read()[0]

# %%
img_lr.shape
# Out:
# (500, 500)

# %% [markdown]
# ## Split image into 64\*64 images

# %%
M, N = 64, 64
images_tiles = [
    img_lr[x : x + M, y : y + N]
    for x in range(0, img_lr.shape[0], M)
    for y in range(0, img_lr.shape[1], N)
]

# %%
# we get 169 images
len(images_tiles)
# Out:
# 64

# %%
H, W = img_lr.shape
if W % M == 0:
    n_w = int(W / M)
else:
    n_w = int(W / M) + 1
if H % N == 0:
    n_h = int(H / N)
else:
    n_h = int(H / N) + 1

# %%
# for i in images_tiles:
#   print(i.shape)

# %% [markdown]
# # All tiles to 64x64

# %%
# There are some images that are not 64x64. The goal of this code is to transform all images to 64x64 without changing the information in the images.
new_tiles = []
N_w = n_w
new_tiles = []
tiles_index = []
operation_type = []
added_col_or_arr_number = []
added_col_or_arr_number_last_tile = []
images_tiles = [
    img_lr[x : x + M, y : y + N]
    for x in range(0, img_lr.shape[0], M)
    for y in range(0, img_lr.shape[1], N)
]
for img_index in range(len(images_tiles)):
    if images_tiles[img_index].shape != (64, 64):
        if images_tiles[img_index].shape[0] == 64:
            # Add pixels (column) from previous tile
            n = 64 - images_tiles[img_index].shape[1]
            # Select the last n columns using negative indexing
            last_n_columns = images_tiles[img_index - 1][:, -n:]
            # Create a new tile by horizontally stacking last_n_columns and images_tiles[img_index]
            new_tile = np.hstack((last_n_columns, images_tiles[img_index]))
            new_tiles.append(new_tile)
            tiles_index.append(img_index)
            operation_type.append("columns added")
            added_col_or_arr_number.append(n)
        if images_tiles[img_index].shape[1] == 64:
            # Add pixels (rows) from previous tile
            n = 64 - images_tiles[img_index].shape[0]
            # Select the last n rows using negative indexing
            last_n_rows = images_tiles[img_index - N_w][-n:, :]
            # Create a new tile by vertically stacking last_n_rows and images_tiles[img_index]
            new_tile = np.vstack((last_n_rows, images_tiles[img_index]))
            # images_tiles[img_index] = new_tile
            new_tiles.append(new_tile)
            tiles_index.append(img_index)
            operation_type.append("rows added")
            added_col_or_arr_number.append(n)
        if (
            images_tiles[img_index].shape[1] != 64
            and images_tiles[img_index].shape[0] != 64
        ):
            index_ = 0
            for index in tiles_index:
                images_tiles[index] = new_tiles[index_]
                index_ += 1
            n_w_ = 64 - images_tiles[img_index].shape[1]
            # Select the last n columns using negative indexing
            last_n_columns = images_tiles[img_index - 1][:, -n_w_:]
            # Create a new tile by horizontally stacking last_n_columns and images_tiles[img_index]
            new_tile_w = np.hstack(
                (
                    last_n_columns[-images_tiles[img_index].shape[0] :, :],
                    images_tiles[img_index],
                )
            )
            n_h_ = 64 - images_tiles[img_index].shape[0]
            # Select the last n rows using negative indexing
            last_n_rows = images_tiles[img_index - N_w][-n_h_:, :]
            # Create a new tile by vertically stacking last_n_rows and images_tiles[img_index]
            new_tile = np.vstack((last_n_rows, new_tile_w))
            # Replace the current tile with the new tile
            images_tiles[img_index] = new_tile
            tiles_index.append(img_index)
            operation_type.append("rows and columns added")
            added_col_or_arr_number_last_tile.append(n_w_)
            added_col_or_arr_number_last_tile.append(n_h_)

# %%
# save images
index = 0
path = "/home/s1300211/Documents/DEM-Super-Resolution/dataset/"
for img in images_tiles:
    tiff.imwrite(path + "/" + "lr_test_" + str(index) + ".tif", img)
    index += 1

# %%
for index in range(10):
    fp = r"/home/s1300211/Documents/DEM-Super-Resolution/dataset/lr_test_" + str(index) + ".tif"
    img = rasterio.open(fp)
    show(img)
# Out:
# /home/s1300211/Documents/venv_2/lib/python3.10/site-packages/rasterio/__init__.py:356: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
# for i in images_tiles:
#   print(i.shape)

# %% [markdown]
# ## Use the model to get HR

# %%
for i in range(len(images_tiles)):
    filename = DATBASE_PATH + "/lr_test_"
    img_hr = io.imread(filename + str(i) + ".tif")
    a = img_hr
    a1 = a
    a111 = a[:, :64]
    a2 = (a1 - 0) / (133.8791 / 2) - 1   # a2 = (a1) / ((932.4479 - 0) / 2) - 1 がもとです。
    a3 = np.expand_dims(a2, 0)
    a4 = np.expand_dims(a3, 0)
    a5 = a4.astype(np.float32)
    a6 = torch.tensor(a5)
    Tensor = torch.cuda.FloatTensor
    a7 = Variable(a6.type(Tensor))
    a8 = generator(a7)
    a9 = (a8 + a7) / 2
    a10 = (a9 + 1) * ((h - l) / 2) + l      # 最後に +ｌを追加
    a11 = a10.cpu().detach().numpy()
    tiff.imwrite(DATBASE_PATH + "gene_hr" + str(i) + ".tif", a11[0, 0, :, :])

# %% [markdown]
# # Visualize HR results

# %%
# generated image
import rasterio
from rasterio.plot import show

for index in range(20):
    fp = r"/home/s1300211/Documents/DEM-Super-Resolution/dataset/gene_hr" + str(index) + ".tif"
    img = rasterio.open(fp)
    show(img)
# Out:
# /home/s1300211/Documents/venv_2/lib/python3.10/site-packages/rasterio/__init__.py:356: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %% [markdown]
# ## Recover the original image

# %%
gene_images_tiles = []
for index in range(len(images_tiles)):
    fp = r"/home/s1300211/Documents/DEM-Super-Resolution/dataset/gene_hr" + str(index) + ".tif"
    img = rasterio.open(fp)
    gene_images_tiles.append(np.squeeze(img.read()))

# %%
# for i in gene_images_tiles:
#   print(i.shape)

# %%
len(added_col_or_arr_number)
# Out:
# 14

# %%
operation_type
# Out:
# ['columns added',
#  'columns added',
#  'columns added',
#  'columns added',
#  'columns added',
#  'columns added',
#  'columns added',
#  'rows added',
#  'rows added',
#  'rows added',
#  'rows added',
#  'rows added',
#  'rows added',
#  'rows added',
#  'rows and columns added']

# %%
# This code recovers the original tiles' shape (because not all original images are 64x64)
for index_index, index in enumerate(tiles_index):
    if operation_type[index_index] == "columns added":
        n = added_col_or_arr_number[index_index]
        gene_images_tiles[index] = gene_images_tiles[index][:, n:]
    if operation_type[index_index] == "rows added":
        n = added_col_or_arr_number[index_index]
        gene_images_tiles[index] = gene_images_tiles[index][n:, :]
    if operation_type[index_index] == "rows and columns added":
        n_w, n_h = (
            added_col_or_arr_number_last_tile[0],
            added_col_or_arr_number_last_tile[1],
        )
        gene_images_tiles[-1] = gene_images_tiles[-1][:, n_w:]
        gene_images_tiles[-1] = gene_images_tiles[-1][n_h:, :]

# %%
# for i in gene_images_tiles:
#   print(i.shape)

# %%
path = "/home/s1300211/Documents/DEM-Super-Resolution/dataset/"
index = 0
for img in gene_images_tiles:
    tiff.imwrite(path + "/" + "original_hr_" + str(index) + ".tif", img)
    index += 1

# %%
for index in range(20):
    fp = r"/home/s1300211/Documents/DEM-Super-Resolution/dataset/original_hr_" + str(index) + ".tif"
    img = rasterio.open(fp)
    show(img)

# %%
# function to recover the original image of (812 * 826)
H, W = img_lr.shape
if W % M == 0:
    n_w = int(W / M)
else:
    n_w = int(W / M) + 1
if H % N == 0:
    n_h = int(H / N)
else:
    n_h = int(H / N) + 1
reversed_array_h = []
a = 0
for i in range(n_h):
    split_arrays = []
    for j in range(a, n_w + a):
        split_arrays.append(gene_images_tiles[j])
    reversed_array = np.concatenate(
        split_arrays, axis=1
    )  # Concatenate the split arrays horizontally
    reversed_array_h.append(reversed_array)
    a = j + 1
reversed_array_final = np.concatenate(reversed_array_h, axis=0)
tiff.imwrite(path + "/gene_test_imge.tif", reversed_array_final)
print(reversed_array_final.shape)
# Out:
# (500, 500)

# %% [markdown]
# ## Comparison: Original vs Super-Resolution DEM
#
# 超解像度処理前後のDEM画像を並べて表示して、改善を視覚的に確認します。

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable
import rasterio

# Load the original test DEM
test_dem_path = os.path.join(BASE_DIR, "datasets", "test", "center_tile.tif")
with rasterio.open(test_dem_path) as src:
    original_dem = src.read(1)

# Load the super-resolution DEM
with rasterio.open(path + "/gene_test_imge.tif") as src:
    sr_dem = src.read(1)

# Create figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(16, 7))

# Normalize data for consistent coloring
vmin = min(original_dem.min(), sr_dem.min())
vmax = max(original_dem.max(), sr_dem.max())
norm = Normalize(vmin=vmin, vmax=vmax)

# Plot original DEM
im1 = axes[0].imshow(original_dem, cmap='viridis', norm=norm)
axes[0].set_title('Original DEM (Input)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('X (pixels)')
axes[0].set_ylabel('Y (pixels)')
axes[0].grid(True, alpha=0.3)

# Plot super-resolution DEM
im2 = axes[1].imshow(sr_dem, cmap='viridis', norm=norm)
axes[1].set_title('Super-Resolution DEM (Generated)', fontsize=14, fontweight='bold')
axes[1].set_xlabel('X (pixels)')
axes[1].set_ylabel('Y (pixels)')
axes[1].grid(True, alpha=0.3)

# Add colorbar
cbar = plt.colorbar(ScalarMappable(norm=norm, cmap='viridis'), ax=axes, orientation='vertical', pad=0.02)
cbar.set_label('Elevation (m)', fontsize=12)

# Add information text
fig.text(0.5, 0.02, f'Original Shape: {original_dem.shape} | Super-Resolution Shape: {sr_dem.shape}', 
         ha='center', fontsize=11, bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))

plt.tight_layout(rect=[0, 0.04, 1, 1])
plt.show()

# Print statistics
print("=" * 60)
print("DEM Comparison Statistics")
print("=" * 60)
print(f"\nOriginal DEM (Input from {test_dem_path}):")
print(f"  Shape: {original_dem.shape}")
print(f"  Min Elevation: {original_dem.min():.2f} m")
print(f"  Max Elevation: {original_dem.max():.2f} m")
print(f"  Mean Elevation: {original_dem.mean():.2f} m")
print(f"  Std Deviation: {original_dem.std():.2f} m")

print(f"\nSuper-Resolution DEM:")
print(f"  Shape: {sr_dem.shape}")
print(f"  Min Elevation: {sr_dem.min():.2f} m")
print(f"  Max Elevation: {sr_dem.max():.2f} m")
print(f"  Mean Elevation: {sr_dem.mean():.2f} m")
print(f"  Std Deviation: {sr_dem.std():.2f} m")

print(f"\nDifference:")
print(f"  Mean Difference: {abs(sr_dem.mean() - original_dem.mean()):.2f} m")
print(f"  RMSE: {np.sqrt(np.mean((sr_dem - original_dem) ** 2)):.2f} m")
print("=" * 60)
# Out:
# /tmp/ipykernel_1633529/650320335.py:45: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0.04, 1, 1])
# ============================================================
# DEM Comparison Statistics
# ============================================================
#
# Original DEM (Input from /home/s1300211/Documents/datasets/test/center_tile.tif):
#   Shape: (500, 500)
#   Min Elevation: 482.37 m
#   Max Elevation: 1414.82 m
#   Mean Elevation: 1168.18 m
#   Std Deviation: 166.93 m
#
# Super-Resolution DEM:
#   Shape: (500, 500)
#   Min Elevation: 2484.04 m
#   Max Elevation: 5875.53 m
#   Mean Elevation: 5000.40 m
#   Std Deviation: 588.39 m
#
# Difference:
#   Mean Difference: 3832.23 m
#   RMSE: 3855.34 m
# ============================================================
